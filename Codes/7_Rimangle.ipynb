# %% [markdown]
# # RE-MANGLE spectra
# We need to re-mangle spectra because what we did in the 2dim fitting is "in principle" wrong.
#
# In the 2dim grid we compared synthetic photometry @ average filter wavelength with Flux spectral density.
# You should use eff wavelength, which is avg filter wavelength weighted for the underlying SED.
#
# Now that we have extrapolated an approximated estimate of the underlying SEDs we need to iterativly warp&re-measure eff wvl of the SED until observed photometry and synthesized photometry is matching.
#
# Read Section 2.2.2 of the paper if you are confused!!

# %%
import os
#COCO_PATH=os.environ['COCO_PATH']
COCO_PATH="/Users/ravkaur/Desktop/research/kilonova-SED/PyCoCo_templates/"
DATALC_PATH = COCO_PATH+"/Inputs/Photometry/4_LCs_late_extrapolated/"
DATASPEC_PATH = COCO_PATH+"/Inputs/Spectroscopy/"

DATAINFO_PATH= COCO_PATH+"Inputs/SNe_Info/"
FILTER_PATH = COCO_PATH+"Inputs/Filters/"

OUTPUT_DIR = COCO_PATH+"Outputs/"

import sys
sys.path.insert(0, COCO_PATH+'what_the_flux/')
import what_the_flux as wtf

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
import pandas as pd
from astropy.io import fits
from scipy import interpolate
from scipy import integrate
import scipy.optimize as opt
import sncosmo

import matplotlib.cm as cm
import scipy
from itertools import cycle

import george
from george.kernels import ExpSquaredKernel, ConstantKernel, Matern32Kernel

import astropy.units as u
# %matplotlib inline

# %%
### I NEED TO ASSUME SOME COSMOLOGY IF I WANT TO GET ABSOLUTE FLUX TEMPLATES (AS IF THEY WERE AT 10pc)
import astropy.cosmology
mycosmo = astropy.cosmology.FlatLambdaCDM(Om0=0.3, H0=70)

# %%
color_dict = {'Bessell_U': 'blue', 'Bessell_B': 'royalblue','Bessell_V':  'limegreen',
              'Bessell_R':  'red', 'Bessell_I':  'mediumvioletred',
              'sdss_g':'darkgreen','ptf_g':'darkgreen', "sdss_g'":'darkgreen','sdss_i':'indianred',
              "sdss_i'":'indianred','sdss_r': 'darkred', "sdss_r'":'darkred','sdss_z':'sienna', "sdss_z'":'sienna',
              'sdss_u': 'darkblue', "sdss_u'": 'darkblue', 'Y':'salmon','H':'darkred', 'J':  'k',
              'Ks':  'brown','K':  'brown', 'swift_UVW1':'indigo', 'swift_UVW2':'darkblue',
               'swift_UVM2':'darkmagenta','swift_U':'plum','swift_V':'teal','swift_B':'powderblue'}

mark_dict = {'Bessell_U': 'o','Bessell_B': 'o', 'Bessell_V':'o', 'Bessell_R':'o', 'Bessell_I': 'o', 
             'sdss_g':'s','ptf_g':'s', "sdss_g'":'s', 'sdss_i':'s', "sdss_i'":'s',
                'sdss_r':'s', "sdss_r'":'s', 'sdss_z':'s', "sdss_z'":'s', 'sdss_u': 's', "sdss_u'": 's',
                'Y':  'o','H':  'o', 'J':  'o', 'Ks':  'o','K':  'o',
                'swift_UVW1':'D', 'swift_UVW2':'D', 'swift_UVM2':'D', 'swift_U':'D',
                'swift_V':'D', 'swift_B':'D'}

CSP_SNe = ['SN2004fe', 'SN2005bf', 'SN2006V', 'SN2007C', 'SN2007Y',
           'SN2009bb',  'SN2008aq', 'SN2006T', 'SN2004gq', 'SN2004gt',
           'SN2004gv','SN2006ep', 'SN2008fq', 'SN2006aa']

#exclude_filt = ['H', 'J', 'K', 'Ks','KS', 'Y']

convert2mjd = (lambda x: float(x.replace('_spec_extended.txt','')\
                               .replace('_spec_extended_FL.txt','')\
                               .replace('_spec_extended_SMOOTH.txt','')))

exclude_filt = ['H','Ks', 'J', 'K']

# %%
info_objects = pd.read_csv(DATAINFO_PATH+'info.dat', comment='#', delimiter=' ')

# %%
def calc_lam_eff(wls, transmission, flux):
    return (integrate.trapezoid(transmission*flux*wls, wls)/\
            integrate.trapezoid(transmission*flux, wls))

def prop_err_div(x,y,sig_x,sig_y):
    return ((sig_x/y)**2  +  ((x*sig_y)/y**2)**2 )**0.5

# %%
class ReMangle_SingleSpectrumClass():
    """Class to load and mangle a single spectrum:
    """
    
    def __init__(self, snname, twodim=True, spec_file=None, verbose=False):
        """
        """
        ## Initialise the class variables            
        self.snname = snname
        self.check_results_folder()
        self.extension_type='2dim' if twodim else 'classic'
        self.create_FINALspec_folder()
        
        if spec_file is None:
            print ("Choose one spec_file from this list:")
            print (self.get_spec_list())
        else:
            self.spec_file = spec_file
            print ('self.spec_file', self.spec_file)
            self.load_manglingfile()
        self.load_final_info()

    def check_results_folder(self):
        results_directory = OUTPUT_DIR+'/%s/'%self.snname
        if not os.path.exists(results_directory):
            print ("I cant mangle a spectrum if I theres no fitted LC yet")
        else: self.results_mainpath = results_directory

    def check_extended_file(self):
        if self.extension_type == '2dim':
            mangled_file_path = OUTPUT_DIR+'/%s/TwoDextended_spectra/%s'%(self.snname,\
                                                                                      self.spec_file)
        else:
            mangled_file_path = OUTPUT_DIR+'/%s/extended_spectra/%s'%(self.snname,\
                                                                                      self.spec_file)
        if not os.path.isfile(mangled_file_path):
            print ("Sorry, This object %s has not mangled file"%mangled_file_path)
        else: 
            self.mangled_file_path = mangled_file_path

    def get_spec_list(self, verbose=False):
        if self.extension_type == '2dim':
            extended_files_path = OUTPUT_DIR+'/%s/TwoDextended_spectra/'%(self.snname)
        else:
            extended_files_path = OUTPUT_DIR+'/%s/extended_spectra/'%(self.snname)

        self.extended_files_path = extended_files_path
        onlyfiles = [f for f in os.listdir(extended_files_path) \
                         if os.path.isfile(os.path.join(extended_files_path, f)) if 'extended.txt' in f]
        return onlyfiles

    def check_spec_manglingphot(self):
        all_specs = self.get_spec_list()
        mangling_file = self.results_mainpath+'fitted_phot4mangling_%s.dat'%self.snname
        phot4mangling = pd.read_csv(mangling_file, sep='\t')
        for spec_file in all_specs:
            file_mjd = float(spec_file.replace('_spec_extended.txt',''))
            mask = phot4mangling['spec_mjd'].values == file_mjd
            if len(phot4mangling[mask])==0:
                print ('There.s no magnling photometry fro this. Are you sure nothing went wrong?', spec_file)
                print ('I compared', phot4mangling['spec_mjd'].values ,file_mjd)

    def get_FLAGGED_spec_list(self, verbose=False):
        if self.extension_type == '2dim':
            extended_files_path = OUTPUT_DIR+'/%s/TwoDextended_spectra/'%(self.snname)
        else:
            extended_files_path = OUTPUT_DIR+'/%s/extended_spectra/'%(self.snname)

        self.extended_files_path = extended_files_path
        onlyfiles = [f for f in os.listdir(extended_files_path) \
                         if os.path.isfile(os.path.join(extended_files_path, f)) if 'extended_FL.txt' in f]
        return onlyfiles

    def get_SMOOTH_spec_list(self, verbose=False):
        if self.extension_type == '2dim':
            extended_files_path = OUTPUT_DIR+'/%s/TwoDextended_spectra/'%(self.snname)
        else:
            extended_files_path = OUTPUT_DIR+'/%s/extended_spectra/'%(self.snname)

        self.extended_files_path = extended_files_path
        onlyfiles = [f for f in os.listdir(extended_files_path) \
                         if os.path.isfile(os.path.join(extended_files_path, f)) if 'extended_SMOOTH.txt' in f]
        return onlyfiles


    def get_SNF_spec_list(self, verbose=False):
        if self.extension_type == '2dim':
            extended_files_path = OUTPUT_DIR+'/%s/TwoDextended_spectra/'%(self.snname)
        else:
            extended_files_path = OUTPUT_DIR+'/%s/extended_spectra/'%(self.snname)

        self.extended_files_path = extended_files_path
        onlyfiles = [f for f in os.listdir(extended_files_path) \
                         if os.path.isfile(os.path.join(extended_files_path, f)) if 'extended_SNF.txt' in f]
        return onlyfiles

    
    def load_original_phot(self, verbose = False):
        SNphotometry_PATH = os.path.join(OUTPUT_DIR+'/%s/fitted_phot_%s.dat'%(self.snname,self.snname))
        #lc_file = np.genfromtxt(SNphotometry_PATH, names=True, dtype=None,encoding="utf-8")
        lc_pd = pd.read_csv(SNphotometry_PATH, sep='\t')
        self.original_phot = lc_pd
        return lc_pd
    
    def load_manglingfile(self):
        if not hasattr(self, "results_mainpath"):
            self.check_results_folder()
        else:
            if (not 'FL.txt' in self.spec_file)&(not 'SNF.txt' in self.spec_file)&(not 'SMOOTH.txt' in self.spec_file):
                mangling_file = self.results_mainpath+'fitted_phot4mangling_%s.dat'%self.snname
                phot4mangling = pd.read_csv(mangling_file, sep='\t')
                file_mjd = convert2mjd(self.spec_file)
                mask = phot4mangling['spec_mjd'].values == file_mjd
                self.phot4mangling = (phot4mangling[mask])
                if len(self.phot4mangling)<1:
                    raise Exception(""" ### ERROR: 
                    I looked in the file with the PHOTOMETRY for MANGLING 
                    (i.e. fitted_phot4mangling_SNNAME.dat).
                    I was loading the photometry to mangle/extend the spectrum you are currently loading
                    in the GRID. I found NO photometry for it... Maybe you should re run GP fit or check your list of spec.""")

                self.avail_filters = [col.replace('_fitflux','') for col in phot4mangling.columns\
                                      if col[-8:]=='_fitflux']
                #Rav aded this to skip H, J, K for now because causing errors
                self.avail_filters = [f for f in self.avail_filters if f not in exclude_filt]
                
            elif 'SNF.txt' in self.spec_file: 
                phot4mangling = self.load_original_phot()
                file_mjd = float(self.spec_file.replace('_spec_extended_SNF.txt',''))
                
                mask = phot4mangling.index == np.argmin(np.abs(phot4mangling['MJD'].values - file_mjd))
                new_columns =[]
                for c in phot4mangling.columns:
                    if ('_err' not in c)&('MJD' not in c): new_columns.append(c+'_fitflux')
                    elif ('_err' in c): new_columns.append(c.replace('_err','')+'_fitfluxerr')
                    elif ('MJD' in c): new_columns.append('spec_mjd')
                phot4mangling.columns = new_columns 
                self.phot4mangling = phot4mangling[mask]
                self.avail_filters = [col.replace('_fitflux','') for col in phot4mangling.columns\
                                      if col[-8:]=='_fitflux']
                
                #Rav aded this to skip H, J, K for now because causing errors
                self.avail_filters = [f for f in self.avail_filters if f not in exclude_filt]
            else: 
                phot4mangling = self.load_original_phot()
                file_mjd = convert2mjd(self.spec_file)
                mask = phot4mangling.index == np.argmin(np.abs(phot4mangling['MJD'].values - file_mjd))
                new_columns =[]
                for c in phot4mangling.columns:
                    if ('_err' not in c)&('MJD' not in c): new_columns.append(c+'_fitflux')
                    elif ('_err' in c): new_columns.append(c.replace('_err','')+'_fitfluxerr')
                    elif ('MJD' in c): new_columns.append('spec_mjd')
                phot4mangling.columns = new_columns 
                self.phot4mangling = phot4mangling[mask]
                self.avail_filters = [col.replace('_fitflux','') for col in phot4mangling.columns\
                                      if col[-8:]=='_fitflux']
                #Rav aded this to skip H, J, K for now because causing errors
                self.avail_filters = [f for f in self.avail_filters if f not in exclude_filt]

    def load_extended_spec(self):
        if not hasattr(self, 'extended_files_path'):
            lista = self.get_spec_list()
        ext_spec = np.genfromtxt(self.extended_files_path+self.spec_file,\
                                     dtype=None, encoding="utf-8", names=['wls', 'flux', 'fluxerr'])
        self.ext_spec = ext_spec
        return ext_spec
  
    def create_mangledspec_folder(self):
        mangledspec_directory = OUTPUT_DIR+'/%s/RE_mangled_spectra_%s/'%(self.snname, self.extension_type)
        if not os.path.exists(mangledspec_directory):
            os.makedirs(mangledspec_directory)
        self.mangledspec_path = mangledspec_directory
   
    def create_FINALspec_folder(self):
        FINAL_directory = OUTPUT_DIR+'/%s/FINAL_spectra_%s/'%(self.snname, self.extension_type)
        if not os.path.exists(FINAL_directory):
            os.makedirs(FINAL_directory)
        if not os.path.exists(FINAL_directory+'/HostNotCorr/'):
            os.makedirs(FINAL_directory+'/HostNotCorr/')
        if not os.path.exists(FINAL_directory+'/as_observed/'):
            os.makedirs(FINAL_directory+'/as_observed/')
            
        self.FINALspec_path = FINAL_directory

    def calculate_ratios4mangling(self, use_what_4phot=None):
        ratios=[]
        ratios_err=[]
        fitted_phot_list=[]
        fitted_photerr_list=[]
        wls_eff=[]
        used_filters=[]
        
        outMJD_ratios=[]
        outMJD_ratios_err=[]
        outMJD_fitted_phot_list=[]
        outMJD_fitted_photerr_list=[]
        outMJD_wls_eff=[]
        outMJD_used_filters=[]
        for filt in self.avail_filters:
            fitted_phot = self.phot4mangling['%s_fitflux'%filt].values[0]
            fitted_phot_err = self.phot4mangling['%s_fitfluxerr'%filt].values[0]
            
            if '%s_inrange'%filt in self.phot4mangling.columns: 
                inMJDrange_pnt = self.phot4mangling['%s_inrange'%filt].values[0]
            else: # this means the spectrum is synthesized from the 2dim surface
                inMJDrange_pnt = ~np.isnan(fitted_phot)

            lam_eff, raw_phot, raw_phot_err = self.band_flux(filt, use_what = use_what_4phot)

            # reject bad data before appending to anything
            if (
                np.isnan(fitted_phot) or
                np.isnan(raw_phot) or
                np.isnan(fitted_phot_err) or
                raw_phot == 0 or
                np.isinf(fitted_phot_err / fitted_phot)
            ):
                print(f"Skipping {filt} due to bad values: fitted_phot={fitted_phot}, raw_phot={raw_phot}, fitted_phot_err={fitted_phot_err}")
                continue

            if (not inMJDrange_pnt):
                outMJD_fitted_phot_list.append(fitted_phot)
                outMJD_fitted_photerr_list.append(fitted_phot_err)
                outMJD_ratios.append(fitted_phot/raw_phot)
                                #outMJD_ratios_err.append( prop_err_div(fitted_phot, raw_phot, fitted_phot_err, raw_phot_err) )
                outMJD_ratios_err.append( prop_err_div(fitted_phot, raw_phot, fitted_phot_err, 0.) )
                outMJD_wls_eff.append(lam_eff)
                outMJD_used_filters.append(filt)
            else:
                fitted_phot_list.append(fitted_phot)
                fitted_photerr_list.append(fitted_phot_err)
                ratios.append(fitted_phot/raw_phot)
                #ratios_err.append( prop_err_div(fitted_phot, raw_phot, fitted_phot_err, raw_phot_err) )
                ratios_err.append( prop_err_div(fitted_phot, raw_phot, fitted_phot_err , 0.) )
                wls_eff.append(lam_eff)
                used_filters.append(filt)
        #print ('ratios',len(ratios))
        ratios = np.array(ratios)
        wls_eff = np.array(wls_eff)
        ratios_err = np.array(ratios_err)
        used_filters = np.array(used_filters)
        outMJD_wls_eff = np.array(outMJD_wls_eff)
        outMJD_used_filters = np.array(outMJD_used_filters)

        
        self.fitted_phot_dict = {'eff_wls':wls_eff, 'fitted_phot':fitted_phot_list,\
                                     'fitted_phot_err':fitted_photerr_list, 'used_filters': used_filters}

        return ratios, ratios_err, wls_eff, used_filters, outMJD_wls_eff, outMJD_used_filters

    def GP_interpolation_mangle(self, wls_eff, ratios, ratios_err, min_scale, optimization=True):
        if len(self.ext_spec['wls'])>10**4:
            # GP struggle to handle such a big number of points
            int_fraction = int(len(self.ext_spec['wls'])/5000.)
            print ('This spectrum has a huge amount of data points(%i), Im chopping a %i th of them'%(len(self.ext_spec['wls']), int_fraction))
            full_wls = self.ext_spec['wls'][::int_fraction]
        else:
            full_wls = self.ext_spec['wls']
        
        norm_wls = np.median(full_wls)
        full_wls_normed = full_wls/norm_wls
        wls_eff_normed = np.array(wls_eff)/norm_wls
            
        offset=1.
        #changed this
        #norm = np.mean(ratios)
        norm = np.nanmean(ratios)
        ratios_normed = np.array(ratios)/norm-offset
        ratios_err_normed = np.array(ratios_err)/norm

        print(f'ratios: {ratios}')
        print(f'ratios normed: {ratios_normed}')
        print(f'ratios err: {ratios_err}')
        print(f'ratios err normed: {ratios_err_normed}')
        print(f'mean: {norm}')
        
        if len(ratios_normed)<1:
            return np.ones(len(full_wls_normed))*np.nan, np.ones(len(full_wls_normed))*np.nan
        else:
            def ll(p):
                #print (np.exp(p))
                if (np.exp(p)[1]<5*10**-3):#|(np.exp(p)[1]>10**5):
                    return np.inf
                else:
                    gp.set_parameter_vector(p)
                    return -gp.lnlikelihood(ratios_normed, quiet=False)#
            def grad_ll(p):
                gp.set_parameter_vector(p)
                return -gp.grad_lnlikelihood(ratios_normed, quiet=False)
            #changed this k to skip nans - fix later
            #k= np.var(ratios_normed)*Matern32Kernel(0.3)
            k = np.nanvar(ratios_normed)*Matern32Kernel(0.3)
            print(k)
            wls_eff_normedT = np.atleast_2d(wls_eff_normed).T
            gp = george.GP(k)
            #print("ratios_err_normed:", ratios_err_normed)
            #print("Any NaNs?", np.any(np.isnan(ratios_err_normed)))
            #print("Any infs?", np.any(np.isinf(ratios_err_normed)))
            #print("wls_eff:", wls_eff)
            wls_eff_normedT = np.ravel(wls_eff_normedT)  # or .flatten()
            print("wls_eff_normedT:", wls_eff_normedT)
            #print("Any NaNs in wls_eff_normedT?", np.any(np.isnan(wls_eff_normedT)))
            #print("Any infs in wls_eff_normedT?", np.any(np.isinf(wls_eff_normedT)))
            #print("wls_eff_normedT shape:", wls_eff_normedT.shape)
            #print("ratios_err_normed shape:", ratios_err_normed.shape)
            gp.compute(wls_eff_normedT, (ratios_err_normed))
            #gp.compute(wls_eff_normedT, ratios_err_normed)
            if optimization:
                try:
                    p0=gp.get_parameter_vector()
                    results = opt.minimize(ll, p0, jac=grad_ll)
                    print ('SCALE:',  '%.4f'%np.exp(results.x[1]))
                except:
                    pass
                    print ('*** GP optimization failed ***'*10)
            #print ('results', np.exp(results.x))
            mu, cov = gp.predict(ratios_normed, full_wls_normed)
            std = np.sqrt(np.diag(cov))
                
            if len(self.ext_spec['wls'])>10**4:
                # GP struggle to handle such a big number of points
                mu_full = np.interp(self.ext_spec['wls'], self.ext_spec['wls'][::int_fraction], mu)
                std_full = np.interp(self.ext_spec['wls'], self.ext_spec['wls'][::int_fraction], std)
            else:
                mu_full = mu
                std_full = std
            return norm*(mu_full+offset), np.abs(norm*(std_full))


    def band_flux(self, filter_name, use_what='ext_spectrum'):
        if use_what == 'ext_spectrum':
            spec_flux = self.ext_spec
            #print ('Im using the UNmangled one')
        else:
            spec_flux = self.mangled_spec[use_what]
            #print ('Im using the %s-TIME mangled one'%use_what)

        if 'swift' in filter_name:
            filt_transm = np.genfromtxt(FILTER_PATH+'/Swift/%s.dat'%filter_name,\
                                                 dtype=None, encoding="utf-8", names=['wls', 'flux'])
        elif self.snname in CSP_SNe:
            filt_transm = np.genfromtxt(FILTER_PATH+'/Site3_CSP/%s.txt'%filter_name,\
                                                 dtype=None, encoding="utf-8", names=['wls', 'flux'])
        else:
            filt_transm = np.genfromtxt(FILTER_PATH+'/GeneralFilters/%s.dat'%filter_name,\
                                                 dtype=None, encoding="utf-8", names=['wls', 'flux'])

        #cut_spec = [(spec_flux['wls']>min(filt_transm['wls']))&\
                     #(spec_flux['wls']<max(filt_transm['wls']))]
        cut_spec = (spec_flux['wls']>min(filt_transm['wls']))&\
                     (spec_flux['wls']<max(filt_transm['wls']))
        #cut_ext_spec = spec_flux[cut_spec].copy()
        cut_ext_spec = spec_flux[cut_spec]

        #added these prints
        #print(filter_name)
        #print(len(cut_ext_spec))

        filt_transm_interp_func = interpolate.interp1d(filt_transm['wls'], 
                                                       filt_transm['flux'], 
                                                       kind='linear')
        filt_transm_interp = filt_transm_interp_func(cut_ext_spec['wls'])
        filt_transm_interp_xLambda = filt_transm_interp*cut_ext_spec['wls']
        
        lam_eff = calc_lam_eff(cut_ext_spec['wls'], 
                                        filt_transm_interp, 
                                        cut_ext_spec['flux']) 

        raw_phot = integrate.trapezoid(filt_transm_interp_xLambda*cut_ext_spec['flux'], cut_ext_spec['wls'])/\
                 integrate.trapezoid(filt_transm_interp_xLambda, cut_ext_spec['wls'])
            
        raw_phot_err = (integrate.trapezoid((filt_transm_interp_xLambda*cut_ext_spec['fluxerr'])**2, 
                                        cut_ext_spec['wls']))**0.5/\
                 integrate.trapezoid(filt_transm_interp_xLambda, cut_ext_spec['wls'])
        if use_what == 'ext_spectrum': 
            return lam_eff, raw_phot, raw_phot_err
        else: 
            return lam_eff, raw_phot, raw_phot_err

    def mangle_iteration_function(self):
        print(f"[DEBUG] Starting mangling for: {self.spec_file}")
        if ('FL' in self.spec_file):
            min_scale=0.5
            optimization=False
        else:
            min_scale=0.5#min_scale=5*10**-3
            optimization=False#optimization=True
        
        print("[DEBUG] Calling calculate_ratios4mangling (initial)")
        # 1st iteration        
        ratios_0, ratios_0_err, wls_eff, used_filters, outMJD_wls_eff, outMJD_used_filters =\
            self.calculate_ratios4mangling(use_what_4phot='ext_spectrum')
        
        print("[DEBUG] Calling GP_interpolation_mangle (initial)")
        mang_mask, mang_mask_err = self.GP_interpolation_mangle(wls_eff, ratios_0, 
                                                                ratios_0_err, min_scale, 
                                                                optimization=optimization)

        print("[DEBUG] Applying initial mangling mask")
        mangled_spec = self.ext_spec['flux'] * mang_mask
        mangled_spec_err = ((self.ext_spec['flux'] * mang_mask_err)**2)**0.5

        self.mangled_spec = {0 : np.array([a for a in zip(self.ext_spec['wls'],
                                                            mangled_spec, mangled_spec_err)],
                                     dtype=[('wls', '<f8'), ('flux', '<f8'), ('fluxerr', '<f8')])}
        self.mangling_mask = {0 : (mang_mask, mang_mask_err) }
        
        mangled_phot_list=[]
        for filt in used_filters:
            mangled_phot_list.append(self.band_flux(filt, use_what=0)[1])
        self.magled_photometry_dict = {0 : {'eff_wls': wls_eff, 
                                              'fitted_phot': mangled_phot_list,\
                                           'used_filters': used_filters}}

        # More iterations
        ratios = ratios_0
        max_iteration = 5
        for i in range(max_iteration):
            print(f"[DEBUG] Iteration {i} - max(ratios-1): {np.max(np.abs(ratios-1.))}")
            if max(np.abs(ratios-1.))>0.01:
                print("[DEBUG] Calling calculate_ratios4mangling...")
                #print (i)
                ratios_iter, ratios_iter_err, wls_eff, used_filters, outMJD_wls_eff, outMJD_used_filters =\
                    self.calculate_ratios4mangling(use_what_4phot=(i))
                print("[DEBUG] Calling GP_interpolation_mangle...")
                mang_mask, mang_mask_err = self.GP_interpolation_mangle(wls_eff, ratios_iter, 
                                                                            ratios_iter_err, min_scale, 
                                                                        optimization=optimization)
                #print ('iteration', i,ratios_iter)
                print("[DEBUG] Applying mangling mask to spectrum...")
                mangled_spec = self.mangled_spec[i]['flux'] * mang_mask
                #mangled_spec_err = ( (self.mangled_spec[str(i+1)]['flux'] * mang_mask_err)**2 +\
                #            (self.mangled_spec[str(i+1)]['fluxerr'] * mang_mask)**2 )**0.5
                print("[DEBUG] Saving mangled spectrum and errors...")
                mangled_spec_err = (self.mangled_spec[i]['flux'] * mang_mask_err)

                #print ('save new', (i+1))
                self.mangled_spec[i+1] = np.array([a for a in zip(self.ext_spec['wls'], 
                                                                       mangled_spec, mangled_spec_err)],
                                         dtype=[('wls', '<f8'), ('flux', '<f8'), ('fluxerr', '<f8')])
                
                self.mangling_mask[i+1] = (mang_mask, mang_mask_err)
                print("[DEBUG] Calculating band fluxes...")
                #RAV - TRYING TO REPLACE THIS, SEE IF IT WORKS
                #mangled_phot_list=[]
                #for filt in used_filters:
                    #mangled_phot_list.append(self.band_flux(filt, use_what=i+1)[1])

                print(f"[DEBUG] used_filters = {used_filters}")
                mangled_phot_list = []

                for filt in used_filters:
                    print(f"[DEBUG] Computing band_flux for filter: {filt}")
                    try:
                        phot_val = self.band_flux(filt, use_what=4)[1]
                        if not np.isfinite(phot_val):
                            print(f"[WARNING] band_flux returned non-finite value for {filt}: {phot_val}")
                        mangled_phot_list.append(phot_val)
                    except Exception as e:
                        print(f"[ERROR] band_flux failed for filter {filt}: {e}")
                        break
                #down to here is what i added
                self.magled_photometry_dict[i+1] = {'eff_wls': wls_eff, 'fitted_phot': mangled_phot_list,\
                                                       'used_filters': used_filters}
                ratios = np.copy(ratios_iter)
                print(f"[DEBUG] Finished iteration {i}")
            else:
                pass
        self.mangling_mask_FINAL = mangled_spec/self.ext_spec['flux']
        iters_list = list(self.mangled_spec.keys())
        last_iter = iters_list[-1]
        #print ('last_iter', last_iter)
        self.final_mangled_spec = self.mangled_spec[last_iter]
        spec_number = self.phot4mangling.spec_mjd.values[0]#self.phot4mangling.index.values[0]

        print('skipping plotting for now')
        '''

        print(f"[DEBUG] Plotting results for file: {self.spec_file}")
        matplotlib.use('Agg')
        fig=plt.figure(1, figsize=(10,6))
        print("[DEBUG] Created figure")
        ax1 = plt.subplot2grid((3,1), (0,0))
        print("[DEBUG] Plotting ax1 data")
        for f,w,r,rerr in zip(used_filters, wls_eff,\
                              ratios_0, ratios_0_err):
            ax1.errorbar(w, r, yerr=rerr, marker='o', mfc= color_dict[f], mec=color_dict[f], linestyle='None',\
                     ecolor= color_dict[f], label='%s'%f)
        #print (iters_list)
        for it in (iters_list):
            mask, mask_err = self.mangling_mask[it]
            ax1.errorbar(self.ext_spec['wls'], mask, color='orange', lw=0.3, alpha=0.5)
            ax1.fill_between(self.ext_spec['wls'], mask-mask_err, mask+mask_err, 
                             color='orange',alpha=0.3)
        ax1.errorbar(self.ext_spec['wls'], self.mangling_mask_FINAL, 
                     color='red', linestyle=':', lw=1.5, alpha=0.9)
        ax1.fill_between(self.ext_spec['wls'], self.mangling_mask_FINAL-mask_err, self.mangling_mask_FINAL+mask_err,
                     facecolor='red', alpha=0.5)

        ax1.set_ylabel('Phot from LCfitting /\n Phot from Raw Spec')
        ax1.set_xlabel('Effective Wavelenght')
        ax1.set_title('%s: Mangled spectrum %s'%(self.snname, self.spec_file))
        ax1.set_xlim(1600., 10500.)
        ax1.legend(ncol=5, fontsize=6)

        #print('eff_wls length:', len(self.fitted_phot_dict['eff_wls']))
        #print('fitted_phot length:', len(self.fitted_phot_dict['fitted_phot']))
        #print('fitted_phot_err length:', len(self.fitted_phot_dict['fitted_phot_err']))
        print("[DEBUG] Plotting ax2 data")
        ax2 = plt.subplot2grid((3,1), (1,0), rowspan=2)
        print("[DEBUG] Checking NaN/inf in mangled_spec...")
        print("wls:", np.any(~np.isfinite(self.mangled_spec[last_iter]['wls'])))
        print("flux:", np.any(~np.isfinite(self.mangled_spec[last_iter]['flux'])))
        print("fluxerr:", np.any(~np.isfinite(self.mangled_spec[last_iter]['fluxerr'])))

        print("[DEBUG] Checking NaN/inf in ext_spec...")
        print("wls:", np.any(~np.isfinite(self.ext_spec['wls'])))
        print("flux:", np.any(~np.isfinite(self.ext_spec['flux'])))

        print("[DEBUG] Checking NaN/inf in fitted phot...")
        print("eff_wls:", np.any(~np.isfinite(self.fitted_phot_dict['eff_wls'])))
        print("fitted_phot:", np.any(~np.isfinite(self.fitted_phot_dict['fitted_phot'])))
        print("fitted_phot_err:", np.any(~np.isfinite(self.fitted_phot_dict['fitted_phot_err'])))

        print("[DEBUG] Checking NaN/inf in magled photometry...")
        print("eff_wls:", np.any(~np.isfinite(self.magled_photometry_dict[last_iter]['eff_wls'])))
        print("fitted_phot:", np.any(~np.isfinite(self.magled_photometry_dict[last_iter]['fitted_phot'])))
        if ('FL' in self.spec_file)|('SNF' in self.spec_file):
            ax2.errorbar(self.mangled_spec[last_iter]['wls'], self.mangled_spec[last_iter]['flux'],\
                     lw=0.7, color='k', linestyle='--', label='Mangled_Spec FAKE SPEC')
        else:
            ax2.errorbar(self.mangled_spec[last_iter]['wls'], self.mangled_spec[last_iter]['flux'],\
                     lw=0.7, color='k', label='Mangled_Spec')

        ax2.errorbar(self.ext_spec['wls'], self.ext_spec['flux'],\
                     lw=0.7, color='r', label='Raw Spec')
        ax2.errorbar(self.fitted_phot_dict['eff_wls'], self.fitted_phot_dict['fitted_phot'],\
                     yerr=self.fitted_phot_dict['fitted_phot_err'], marker='o',
                     linestyle='None', label='Fitted Phot')
        ax2.errorbar(self.magled_photometry_dict[last_iter]['eff_wls'],
                     self.magled_photometry_dict[last_iter]['fitted_phot'],\
                     marker='^', mfc='r', mec='r', linestyle='None', label='Phot from mangled spec')
        ax2.plot(self.magled_photometry_dict[iters_list[-1]]['eff_wls'], 
                 self.magled_photometry_dict[iters_list[-1]]['fitted_phot'],\
                 marker='.', mfc='r', mec = 'None', linestyle='None')
        print ('ITERATION', last_iter, iters_list[-1])
        ax2.fill_between(self.mangled_spec[last_iter]['wls'], 
                         self.mangled_spec[last_iter]['flux']-self.mangled_spec[last_iter]['fluxerr'],\
                         self.mangled_spec[last_iter]['flux']+self.mangled_spec[last_iter]['fluxerr'], 
                         color='grey',alpha=0.3)
        ax2.set_ylabel('Flux erg s-1 cm-2 A-1')
        ax2.set_xlabel('Wavelenght')
        ax2.set_xlim(1600., 10500.)
        ax2.legend()
        print("[DEBUG] Saving figure to ...")
        if (not hasattr(self, 'mangledspec_path')):
            self.create_mangledspec_folder()
        if 'FL' in self.spec_file:
            fig.savefig(self.mangledspec_path+self.spec_file.replace('_spec_extended_FL.txt','_REmangled_spec_FL.png'),
                        bbox_inches='tight')
        elif 'SNF' in self.spec_file:
            fig.savefig(self.mangledspec_path+self.spec_file.replace('_spec_extended_SNF.txt','_REmangled_spec_SNF.pdf'),
                        bbox_inches='tight')
        else:
            fig.savefig(self.mangledspec_path+'%.6f_REmangled_spec.png'%spec_number, bbox_inches='tight')
            
        print("[DEBUG] Plot saved, closing figure")
        plt.close(fig)
        '''
        print(f"[DEBUG] Saving final mangled spectrum")
        self.save_mangled_spectrum()
        return list(self.mangled_spec.keys())

        
    def get_diff_FittedMangled_phot(self):
        fitted_phot = np.array(self.fitted_phot_dict['fitted_phot'])
        fitted_phot_err = np.array(self.fitted_phot_dict['fitted_phot_err'])
        mangled_phot = np.array(self.magled_photometry_dict['fitted_phot'])
        diff_mag = -2.5*np.log10(mangled_phot/fitted_phot)
        
        def err_fromFlux_toMag(flux, err_flux):
            flux = np.array(flux, dtype=float)
            err_flux = np.array(err_flux, dtype=float)
            return 2.5/np.log(10.) * err_flux/flux
    
        fitted_phot_err_mag = err_fromFlux_toMag(fitted_phot, fitted_phot_err)
        discrepancy_mag = diff_mag/fitted_phot_err_mag
        return self.magled_photometry_dict['used_filters'], diff_mag, discrepancy_mag 

    def get_filter_transmission(self, f):
        filt_transm = np.genfromtxt(self.main_path+'filters/%s.dat'%f,\
                                                 dtype=None, encoding="utf-8", names=['wls', 'flux'])
        return filt_transm

    def save_mangled_spectrum(self):

        if (not hasattr(self, 'final_mangled_spec')):
            print ("Mangled spectrum not available. First you have to mangle the spectrum calling self.mangle_spectrum()")
        if (not hasattr(self, 'mangledspec_path')):
            self.create_mangledspec_folder()
        
        save_path = self.mangledspec_path

        spec_number = self.phot4mangling.spec_mjd.values[0]#self.phot4mangling.index.values[0]
        if 'FL' in self.spec_file:
            fout = open(self.mangledspec_path+\
                        self.spec_file.replace('_spec_extended_FL.txt','_REmangled_spec_FL.txt'), 'w')
        elif 'SMOOTH' in self.spec_file:
            fout = open(self.mangledspec_path+\
                        self.spec_file.replace('_spec_extended_SMOOTH.txt','_REmangled_spec_SMOOTH.txt'), 'w')
        elif 'SNF' in self.spec_file:
            fout = open(self.mangledspec_path+\
                        self.spec_file.replace('_spec_extended_SNF.txt','_REmangled_spec_SNF.txt'), 'w')
        else:
            fout = open(self.mangledspec_path+'/%.6f_REmangled_spec.txt'%spec_number, 'w')

        fout.write('#wls\tflux\tfluxerr\n')
        for w,f,ferr in zip(self.ext_spec['wls'], self.final_mangled_spec['flux'], self.final_mangled_spec['fluxerr']):
            fout.write('%E\t%E\t%E\n'%(w,f,ferr))
        fout.close() 
        
        
    def load_final_info(self):
        mask = info_objects.Name==self.snname
        if len(info_objects[mask])==0:
            raise Exception((' !!!!!!!!!!!!! \n I CANT FIND THIS OBJECT IN THE FINAL_info.dat FILE!! \n Add it to the PYCOCO/info/FINAL_info.dat first.'))
        return (info_objects[mask])
        
        
    def save_FINAL_spectrum(self):
        if (not hasattr(self, 'final_mangled_spec')):
            print ("Mangled spectrum not available. First you need to mangle the spectrum calling self.mangle_spectrum()")
        if (not hasattr(self, 'FINALspec_path')):
            self.create_FINALspec_folder()

        flux = self.final_mangled_spec['flux']
        fluxerr = self.final_mangled_spec['fluxerr']
        
        sn_info = self.load_final_info()        
        MWdust = sncosmo.CCM89Dust()
        Hostdust = sncosmo.CCM89Dust()
        r_v = 3.1
        z = sn_info['z'].values[0]
        
        wls = self.ext_spec['wls']
        wls_restframe = self.ext_spec['wls']/(1+z)
        
        # MW corrections in SN restframe
        MW_ebv = sn_info['EBV_MW'].values[0]
        MWdust.parameters = [MW_ebv, r_v]
        MW_extinction_perc = MWdust.propagate(wls_restframe, np.ones(len(flux)))
        
        # Host corrections in SN restframe
        Host_ebv = sn_info['EBV_host'].values[0]
        Hostdust.parameters = [Host_ebv, r_v]
        Host_extinction_perc = Hostdust.propagate(wls, np.ones(len(flux)))

        dist = 10**(mycosmo.distmod(z).value/5.+1)
        To_abs_lum = (dist/10.)**2

        self.final_spec_wls = wls_restframe
        self.HostCorr_spec_flux = To_abs_lum*flux
        self.HostCorr_spec_fluxerr = To_abs_lum*fluxerr

        self.HostNOTCorr_spec_flux = To_abs_lum*flux*Host_extinction_perc
        self.HostNOTCorr_spec_fluxerr = To_abs_lum*fluxerr*Host_extinction_perc
        
        self.as_observed_spec_flux = flux*Host_extinction_perc*MW_extinction_perc
        self.as_observed_spec_fluxerr = fluxerr*Host_extinction_perc*MW_extinction_perc

        spec_number = self.phot4mangling.spec_mjd.values[0]#self.phot4mangling.index.values[0]
        
        
        for path_fold in ['', '/HostNotCorr/','/as_observed/']:
            path = self.FINALspec_path + path_fold
            if 'FL' in self.spec_file:
                fout = open(path+self.spec_file.replace('_spec_extended_FL.txt','_FINAL_spec_FL.txt'), 'w')
            elif 'SMOOTH' in self.spec_file:
                fout = open(path+self.spec_file.replace('_spec_extended_SMOOTH.txt','_FINAL_spec_SMOOTH.txt'), 'w')
            elif 'SNF' in self.spec_file:
                fout = open(path+self.spec_file.replace('_spec_extended_SNF.txt','_FINAL_spec_SNF.txt'), 'w')
            else:
                fout = open(path+'/%.6f_FINAL_spec.txt'%spec_number, 'w')
            fout.write('#wls\tflux\tfluxerr\n')
            if path_fold=='':
                for w,f,ferr in zip(self.final_spec_wls, 
                                self.HostCorr_spec_flux, 
                                self.HostCorr_spec_fluxerr):
                    fout.write('%E\t%E\t%E\n'%(w,f,ferr))
                fout.close() 
            elif path_fold=='/HostNotCorr/':
                for w,f,ferr in zip(self.final_spec_wls, 
                                self.HostNOTCorr_spec_flux, 
                                self.HostNOTCorr_spec_fluxerr):
                    fout.write('%E\t%E\t%E\n'%(w,f,ferr))
                fout.close() 
            
            elif path_fold=='/as_observed/':
                for w,f,ferr in zip(self.final_spec_wls, 
                                self.as_observed_spec_flux, 
                                self.as_observed_spec_fluxerr):
                    fout.write('%E\t%E\t%E\n'%(w,f,ferr))
                fout.close() 

        #if self.snname in Alternative_RV_dict.keys():
        #    different_r_v = 3.1
        #    Host_ebv  = 0.0        
#
#            Hostdust.parameters = [Host_ebv, different_r_v]
#            Host_extinction_perc = Hostdust.propagate(wls, np.ones(len(flux)))
#
#            self.HostNOTCorr_spec_flux = To_abs_lum*flux*Host_extinction_perc
#            self.HostNOTCorr_spec_fluxerr = To_abs_lum*fluxerr*Host_extinction_perc
#

# %%
snname='iPTF13bvn'

# %%
#prepare output folder
# delete if the folder already exist
mangledspec_directory = OUTPUT_DIR+'/%s/RE_mangled_spectra_%s/'%(snname, '2dim')
os.system('rm -rf %s'%mangledspec_directory)
os.makedirs(mangledspec_directory)

FINAL_directory = OUTPUT_DIR+'/%s/FINAL_spectra_%s/'%(snname, '2dim')
os.system('rm -rf %s'%FINAL_directory)
os.makedirs(FINAL_directory)

# %%
# do for KN
snname='AT2017gfo'

#prepare output folder
# delete if the folder already exist
mangledspec_directory = OUTPUT_DIR+'/%s/RE_mangled_spectra_%s/'%(snname, '2dim')
os.system('rm -rf %s'%mangledspec_directory)
os.makedirs(mangledspec_directory)

FINAL_directory = OUTPUT_DIR+'/%s/FINAL_spectra_%s/'%(snname, '2dim')
os.system('rm -rf %s'%FINAL_directory)
os.makedirs(FINAL_directory)

# %% [markdown]
# ### FIRST: Remangle the "true" spectra (i.e. real spectra that we only had to extend in UV)

# %%
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                            spec_file=None, verbose=True)
# Out:
# Choose one spec_file from this list:
# ['57987.980002_spec_extended.txt', '57990.000001_spec_extended.txt', '57985.974001_spec_extended.txt', '57988.990003_spec_extended.txt', '57984.969003_spec_extended.txt', '57991.000003_spec_extended.txt', '57987.980003_spec_extended.txt', '57988.990002_spec_extended.txt', '57984.969002_spec_extended.txt', '57990.000003_spec_extended.txt', '57985.974003_spec_extended.txt', '57988.990001_spec_extended.txt', '57984.969001_spec_extended.txt', '57991.000001_spec_extended.txt', '57987.980001_spec_extended.txt', '57990.000002_spec_extended.txt', '57985.974002_spec_extended.txt', '57983.969002_spec_extended.txt', '57986.974001_spec_extended.txt', '57983.969003_spec_extended.txt', '57986.974002_spec_extended.txt', '57983.969001_spec_extended.txt', '57986.974003_spec_extended.txt']

# %%
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                    spec_file=None, verbose=True)
for a in new_spec.get_spec_list()[:]:
    print (a)
    new_spec= ReMangle_SingleSpectrumClass(snname=new_spec.snname, twodim=True,\
                        spec_file=a, verbose=False)
    new_spec.load_extended_spec()
    result = new_spec.mangle_iteration_function()
    new_spec.save_FINAL_spectrum()
# Out:
# Choose one spec_file from this list:
# ['57987.980002_spec_extended.txt', '57990.000001_spec_extended.txt', '57985.974001_spec_extended.txt', '57988.990003_spec_extended.txt', '57984.969003_spec_extended.txt', '57991.000003_spec_extended.txt', '57987.980003_spec_extended.txt', '57988.990002_spec_extended.txt', '57984.969002_spec_extended.txt', '57990.000003_spec_extended.txt', '57985.974003_spec_extended.txt', '57988.990001_spec_extended.txt', '57984.969001_spec_extended.txt', '57991.000001_spec_extended.txt', '57987.980001_spec_extended.txt', '57990.000002_spec_extended.txt', '57985.974002_spec_extended.txt', '57983.969002_spec_extended.txt', '57986.974001_spec_extended.txt', '57983.969003_spec_extended.txt', '57986.974002_spec_extended.txt', '57983.969001_spec_extended.txt', '57986.974003_spec_extended.txt']
# 57987.980002_spec_extended.txt
# self.spec_file 57987.980002_spec_extended.txt
# Skipping Bessell_I due to bad values: fitted_phot=0.0, raw_phot=3.754352110022587e-17, fitted_phot_err=0.0
# Skipping Bessell_U due to bad values: fitted_phot=0.0, raw_phot=4.753829917940396e-18, fitted_phot_err=0.0
# Skipping H due to bad values: fitted_phot=3.2885913249841243e-17, raw_phot=nan, fitted_phot_err=4.7442038894592326e-18
# Skipping J due to bad values: fitted_phot=4.0306209068516704e-17, raw_phot=nan, fitted_phot_err=2.9289840410852627e-18
# Skipping Ks due to bad values: fitted_phot=2.2605912974997626e-17, raw_phot=nan, fitted_phot_err=3.031456544720713e-18
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [-2.53069619  0.98771876         nan         nan         nan  1.00856728
#  -5.7594894   2.3975258   0.95477147]
# ratios normed: [ 4.16187292 -3.01465461         nan         nan         nan -3.05717942
#  10.74765762 -5.89024466 -2.94745186]
# ratios err: [5.34360743 0.37633445 0.08267572 8.28635235 1.03608455 0.09932736]
# ratios err normed: [-10.89938121  -0.76761114  -0.16863405 -16.90171186  -2.11330653
#   -0.20259848]
# norm: -0.4902670463088136
# ConstantKernel(log_constant=3.4794450104083277, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# ratios_err_normed: [-10.89938121  -0.76761114  -0.16863405 -16.90171186  -2.11330653
#   -0.20259848]
# Any NaNs? False
# wls_eff_normedT: [0.95480671 1.17869557 2.13021824 1.02696936 1.62197956 1.91076607]
# Any NaNs in wls_eff_normedT? False
# Any infs in wls_eff_normedT? False
# wls_eff_normedT shape: (6,)
# ratios_err_normed shape: (6,)
# compute
# <george.solvers.basic.BasicSolver object at 0x1686c3500>
# [[0.95480671]
#  [1.17869557]
#  [2.13021824]
#  [1.02696936]
#  [1.62197956]
#  [1.91076607]]
# [[151.23822306  27.29677657   3.71967253  31.7151663   12.23392784
#     6.35007225]
#  [ 27.29677657  33.03093913   6.41733353  29.71202434  19.18005681
#    10.62166229]
#  [  3.71967253   6.41733353  32.47014971   4.44707473  16.9543915
#    27.45505835]
#  [ 31.7151663   29.71202434   4.44707473 318.10957604  14.24205073
#     7.52528685]
#  [ 12.23392784  19.18005681  16.9543915   14.24205073  36.90777673
#    24.90357082]
#  [  6.35007225  10.62166229  27.45505835   7.52528685  24.90357082
#    32.48275841]]
# Cholesky
# [[151.23822306  27.29677657   3.71967253  31.7151663   12.23392784
#     6.35007225]
#  [ 27.29677657  33.03093913   6.41733353  29.71202434  19.18005681
#    10.62166229]
#  [  3.71967253   6.41733353  32.47014971   4.44707473  16.9543915
#    27.45505835]
#  [ 31.7151663   29.71202434   4.44707473 318.10957604  14.24205073
#     7.52528685]
#  [ 12.23392784  19.18005681  16.9543915   14.24205073  36.90777673
#    24.90357082]
#  [  6.35007225  10.62166229  27.45505835   7.52528685  24.90357082
#    32.48275841]]
# False
# True
# True
# (9,) (6185,)
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_81678/783562861.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   return (integrate.trapezoid(transmission*flux*wls, wls)/\
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_81678/3064491807.py:371: RuntimeWarning: invalid value encountered in scalar divide
#   raw_phot = integrate.trapezoid(filt_transm_interp_xLambda*cut_ext_spec['flux'], cut_ext_spec['wls'])/\
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_81678/3064491807.py:374: RuntimeWarning: invalid value encountered in scalar divide
#   raw_phot_err = (integrate.trapezoid((filt_transm_interp_xLambda*cut_ext_spec['fluxerr'])**2,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 8
#       5 new_spec= ReMangle_SingleSpectrumClass(snname=new_spec.snname, twodim=True,\
#       6                     spec_file=a, verbose=False)
#       7 new_spec.load_extended_spec()
# ----> 8 result = new_spec.mangle_iteration_function()
#       9 new_spec.save_FINAL_spectrum()
#
# Cell In[21], line 393, in ReMangle_SingleSpectrumClass.mangle_iteration_function(self)
#     390 # 1st iteration
#     391 ratios_0, ratios_0_err, wls_eff, used_filters, outMJD_wls_eff, outMJD_used_filters =\
#     392     self.calculate_ratios4mangling(use_what_4phot='ext_spectrum')
# --> 393 mang_mask, mang_mask_err = self.GP_interpolation_mangle(wls_eff, ratios_0,
#     394                                                         ratios_0_err, min_scale,
#     395                                                         optimization=optimization)
#     397 mangled_spec = self.ext_spec['flux'] * mang_mask
#     398 mangled_spec_err = ((self.ext_spec['flux'] * mang_mask_err)**2)**0.5
#
# Cell In[21], line 323, in ReMangle_SingleSpectrumClass.GP_interpolation_mangle(self, wls_eff, ratios, ratios_err, min_scale, optimization)
#     320 #print ('results', np.exp(results.x))
#     321 #added this print
#     322 print(ratios_normed.shape, full_wls_normed.shape)
# --> 323 mu, cov = gp.predict(ratios_normed, full_wls_normed)
#     324 std = np.sqrt(np.diag(cov))
#     326 if len(self.ext_spec['wls'])>10**4:
#     327     # GP struggle to handle such a big number of points
#
# File /opt/anaconda3/envs/SED/lib/python3.12/site-packages/george/gp.py:525, in GP.predict(self, y, t, return_cov, return_var, cache, kernel)
#     485 """
#     486 Compute the conditional predictive distribution of the model. You must
#     487 call :func:`GP.compute` before this function.
#    (...)
#     522
#     523 """
#     524 self.recompute()
# --> 525 alpha = self._compute_alpha(y, cache)
#     526 xs = self.parse_samples(t)
#     528 if kernel is None:
#
# File /opt/anaconda3/envs/SED/lib/python3.12/site-packages/george/gp.py:271, in GP._compute_alpha(self, y, cache)
#     268 if self._alpha is None or not np.array_equiv(y, self._y):
#     269     self._y = y
#     270     r = np.ascontiguousarray(
# --> 271         self._check_dimensions(y) - self._call_mean(self._x),
#     272         dtype=np.float64,
#     273     )
#     274     self._alpha = self.solver.apply_inverse(r, in_place=True).flatten()
#     275 return self._alpha
#
# File /opt/anaconda3/envs/SED/lib/python3.12/site-packages/george/gp.py:257, in GP._check_dimensions(self, y, check_dim)
#     255     raise ValueError("The predicted dimension must be 1-D")
#     256 if len(y) != n:
# --> 257     raise ValueError("Dimension mismatch")
#     258 return y
#
# ValueError: Dimension mismatch

# %%
color=cycle(plt.cm.gnuplot(np.linspace(0,1,int(len(new_spec.get_spec_list())*1.2))))
fig= plt.figure(1, figsize=(10,6))
plt.title(new_spec.snname, fontsize=15)
mean=1.; a=0
for l in new_spec.get_spec_list()[:]:
    new_spec.create_FINALspec_folder()
    sp = np.genfromtxt(new_spec.FINALspec_path+l.replace('spec_extended', 'FINAL_spec'))
    plt.plot(sp[:,0], sp[:,1], #+mean*a, 
             lw=1.5,color=next(color))
    if mean==1.:
        mean = np.median(sp[:,1])*0.2
    a=a+1
    
plt.hlines(0, 1500, 11000, lw=0.7, linestyle='--')
plt.ylabel('Calibrated Flux, Dust corrected [erg s-1 cm-2 AA-1]')
plt.xlabel('wls [AA]')
fig.savefig(new_spec.FINALspec_path+'Final_Spec.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# do for KN
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                            spec_file=None, verbose=True)
# Out:
# Choose one spec_file from this list:
# ['57987.980002_spec_extended.txt', '57990.000001_spec_extended.txt', '57985.974001_spec_extended.txt', '57988.990003_spec_extended.txt', '57984.969003_spec_extended.txt', '57991.000003_spec_extended.txt', '57987.980003_spec_extended.txt', '57988.990002_spec_extended.txt', '57984.969002_spec_extended.txt', '57990.000003_spec_extended.txt', '57985.974003_spec_extended.txt', '57988.990001_spec_extended.txt', '57984.969001_spec_extended.txt', '57991.000001_spec_extended.txt', '57987.980001_spec_extended.txt', '57990.000002_spec_extended.txt', '57985.974002_spec_extended.txt', '57983.969002_spec_extended.txt', '57986.974001_spec_extended.txt', '57983.969003_spec_extended.txt', '57986.974002_spec_extended.txt', '57983.969001_spec_extended.txt', '57986.974003_spec_extended.txt']

# %%
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                    spec_file=None, verbose=True)
for a in new_spec.get_spec_list()[:]:
    print (a)
    new_spec= ReMangle_SingleSpectrumClass(snname=new_spec.snname, twodim=True,\
                        spec_file=a, verbose=False)
    new_spec.load_extended_spec()
    result = new_spec.mangle_iteration_function()
    new_spec.save_FINAL_spectrum()
# Out:
# Choose one spec_file from this list:
# ['57987.980002_spec_extended.txt', '57990.000001_spec_extended.txt', '57985.974001_spec_extended.txt', '57988.990003_spec_extended.txt', '57984.969003_spec_extended.txt', '57991.000003_spec_extended.txt', '57987.980003_spec_extended.txt', '57988.990002_spec_extended.txt', '57984.969002_spec_extended.txt', '57990.000003_spec_extended.txt', '57985.974003_spec_extended.txt', '57988.990001_spec_extended.txt', '57984.969001_spec_extended.txt', '57991.000001_spec_extended.txt', '57987.980001_spec_extended.txt', '57990.000002_spec_extended.txt', '57985.974002_spec_extended.txt', '57983.969002_spec_extended.txt', '57986.974001_spec_extended.txt', '57983.969003_spec_extended.txt', '57986.974002_spec_extended.txt', '57983.969001_spec_extended.txt', '57986.974003_spec_extended.txt']
# 57987.980002_spec_extended.txt
# self.spec_file 57987.980002_spec_extended.txt
# [DEBUG] Starting mangling for: 57987.980002_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [-2.53069619  0.98771876  1.00856728 -5.7594894   2.3975258   0.95477147]
# ratios normed: [ 4.16187292 -3.01465461 -3.05717942 10.74765762 -5.89024466 -2.94745186]
# ratios err: [5.34360743 0.37633445 0.08267572 8.28635235 1.03608455 0.09932736]
# ratios err normed: [-10.89938121  -0.76761114  -0.16863405 -16.90171186  -2.11330653
#   -0.20259848]
# mean: -0.49026704630881346
# ConstantKernel(log_constant=3.4794450104083285, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.95480671 1.17869557 2.13021824 1.02696936 1.62197956 1.91076607]
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 6.759489403855581
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [-16.8379766    1.0186946    1.01402774 -14.82737544   1.33625974
#    0.89054584]
# ratios normed: [ 2.68636459 -1.2230244  -1.22200268  2.24618053 -1.29254944 -1.1949686 ]
# ratios err: [35.55366986  0.38813667  0.08312333 21.33259543  0.57746118  0.0926458 ]
# ratios err normed: [-7.78382063 -0.08497537 -0.01819832 -4.67037853 -0.12642448 -0.02028309]
# mean: -4.56763735285673
# ConstantKernel(log_constant=1.1178480299211304, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [1.10612735 1.20360832 2.13061587 1.08517535 1.61677856 1.89838303]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 17.837976596068682
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [ -92.50987073    1.11617836    1.03679387 -113.31671377    1.03388159
#     0.93428365]
# ratios normed: [ 1.75183062 -1.03320223 -1.03084083  2.37075817 -1.0307542  -1.02779152]
# ratios err: [1.95336143e+02 4.25279320e-01 8.49895499e-02 1.63032198e+02
#  4.46789245e-01 9.71959579e-02]
# ratios err normed: [-5.81053648e+00 -1.26505058e-02 -2.52812855e-03 -4.84961216e+00
#  -1.32903474e-02 -2.89122458e-03]
# mean: -33.617574504378645
# ConstantKernel(log_constant=0.7684366154824133, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.80729461 1.24037958 2.1277304  1.1623673  1.60928851 1.89926984]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 114.3167137700016
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [ 5.20934859  2.10049527  1.23936385 84.24825409  0.94764982  1.03833265]
# ratios normed: [-0.6702368  -0.86703404 -0.92154555  4.33309935 -0.94001169 -0.93427127]
# ratios err: [1.09996269e+01 8.00317613e-01 1.01594906e-01 1.21210522e+02
#  4.09524408e-01 1.08020446e-01]
# ratios err normed: [6.96300517e-01 5.06618610e-02 6.43118047e-03 7.67289202e+00
#  2.59237936e-02 6.83793123e-03]
# mean: 15.797240711045132
# ConstantKernel(log_constant=1.3254134230521544, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.77361984 1.53221989 2.09794347 1.02828353 1.57769334 1.93321983]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 83.24825409408675
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [ 0.83013321  0.44631728  0.97105823 13.6772572   0.72282993  1.17416085]
# ratios normed: [-0.72052142 -0.84973964 -0.6730766   3.60468318 -0.75664691 -0.60469861]
# ratios err: [ 1.75284018  0.17005303  0.07960097 19.67788538  0.31236908  0.12215101]
# ratios err normed: [0.5901237  0.05725127 0.02679903 6.62489755 0.10516441 0.04112423]
# mean: 2.9702927818603864
# ConstantKernel(log_constant=0.9571867348120715, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.75950359 1.69192801 2.09970465 1.10248919 1.51878707 1.97349509]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 12.677257198797216
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(12370), Im chopping a 2 th of them
# ratios: [ 0.82853317  0.48794523  0.99264587 11.20451758  1.01053897  1.12600566]
# ratios normed: [-0.68235528 -0.81293058 -0.61943743  3.29561051 -0.61257754 -0.56830968]
# ratios err: [ 1.74946168  0.18591385  0.08137059 16.12027979  0.43670179  0.1171413 ]
# ratios err normed: [0.67071214 0.07127603 0.03119602 6.18022532 0.16742361 0.04490987]
# mean: 2.608364414003344
# ConstantKernel(log_constant=0.7785174664823233, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.73972651 1.95255533 2.09860279 1.22797248 1.51361771 1.97627806]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57990.000001_spec_extended.txt
# self.spec_file 57990.000001_spec_extended.txt
# [DEBUG] Starting mangling for: 57990.000001_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: [1.05497918 0.         0.67952889 1.06066148]
# ratios normed: [ 0.50971762 -1.         -0.02756684  0.51784922]
# ratios err: [0.59716099 0.         0.11818278 0.06876107]
# ratios err normed: [0.85456139 0.         0.16912431 0.09839985]
# mean: 0.6987923868495638
# ConstantKernel(log_constant=-0.9618506281739099, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.63433624 1.16359365 1.08426268 1.2801847 ]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 1.0
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [  2.03022133   0.         -62.26646505   1.47317513]
# ratios normed: [-1.13819709 -1.          3.23847607 -1.10027898]
# ratios err: [ 1.1491876   0.         10.82930267  0.0955037 ]
# ratios err normed: [-0.07822516 -0.         -0.73715025 -0.00650093]
# mean: -14.69076714770112
# ConstantKernel(log_constant=1.2523224235673702, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.62883634 1.25557603 1.25893613 1.32062044]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 63.26646504539593
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 1.1132354  -0.         36.5368708   1.25684456]
# ratios normed: [-0.88554894 -1.          2.75633352 -0.87078457]
# ratios err: [0.63013638 0.         6.35444508 0.08147932]
# ratios err normed: [0.06478394 0.         0.65329664 0.00837684]
# mean: 9.726737688498499
# ConstantKernel(log_constant=0.9301775784248405, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.6304962  1.32264923 1.2005057  1.37759797]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 35.53687079732632
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 0.77095396 -0.          3.33904051  1.12034637]
# ratios normed: [-0.41039868 -1.          1.55359306 -0.14319437]
# ratios err: [0.43639121 0.         0.58072159 0.07263035]
# ratios err normed: [0.33373825 0.         0.44411759 0.0555454 ]
# mean: 1.307585210433298
# ConstantKernel(log_constant=-0.10464324881927797, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.66731314 1.75394331 1.20479522 1.47466044]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 2.339040512227293
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 0.76805725 -0.          1.25443717  0.89095155]
# ratios normed: [ 0.05450008 -1.          0.72227277  0.22322714]
# ratios err: [0.43475155 0.         0.21817008 0.05775903]
# ratios err normed: [0.59688981 0.         0.29953544 0.07929995]
# mean: 0.728361491058177
# ConstantKernel(log_constant=-0.9323702053589028, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.67336797 1.76751314 1.18810459 1.53337356]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_I
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 1.0
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 0.87134249 -0.          1.02621451  0.83681058]
# ratios normed: [ 0.27465304 -1.          0.50120931  0.22413765]
# ratios err: [0.49321518 0.         0.17847789 0.05424915]
# ratios err normed: [0.72150531 0.         0.26108837 0.07935898]
# mean: 0.6835918954636455
# ConstantKernel(log_constant=-1.0664722946728404, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.67492713 1.67272637 1.18098489 1.55050896]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_I
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57985.974001_spec_extended.txt
# self.spec_file 57985.974001_spec_extended.txt
# [DEBUG] Starting mangling for: 57985.974001_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: [1.57390846 0.         0.51916688 0.87688556 2.53653915 1.29918734
#  0.83988639 1.05106653]
# ratios normed: [ 0.44783126 -1.         -0.52242074 -0.19335694  1.33335087  0.19511654
#  -0.22739232 -0.03312866]
# ratios err: [0.57736439 0.         0.10352981 0.11014498 0.84717128 0.30118773
#  1.15802942 0.14654796]
# ratios err normed: [0.53111488 0.         0.09523661 0.10132187 0.77930903 0.27706123
#  1.06526602 0.1348088 ]
# mean: 1.0870800370828924
# ConstantKernel(log_constant=-0.861695143345869, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.61106644 0.48635114 0.75720783 1.37733937 0.64583087 1.03877863
#  0.87559122 1.22287324]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 1.5365391485188757
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [5.30210895 0.         0.89482541 0.97436573 6.84277732 1.23702136
#  1.0461111  1.02146177]
# ratios normed: [ 1.4491989  -1.         -0.58665402 -0.54991202  2.1608786  -0.42858372
#  -0.51677074 -0.52815699]
# ratios err: [1.94499805 0.         0.17844187 0.1223894  2.28539916 0.28677593
#  1.4423706  0.14242023]
# ratios err normed: [0.89845138 0.         0.08242751 0.05653524 1.05569259 0.13247017
#  0.66627309 0.06578806]
# mean: 2.1648339552351428
# ConstantKernel(log_constant=0.13385603357557296, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.62665728 0.67394883 0.76990287 1.3767153  0.65797891 1.04080731
#  0.88006422 1.21946537]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r'
#  'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 5.842777320504366
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [-4.14629031e+01 -0.00000000e+00  1.24325252e+00  9.94034096e-01
#  -2.59439284e+03  9.96920521e-01  8.41978443e-01  9.84599191e-01]
# ratios normed: [-0.87391521 -1.         -1.00378061 -1.00302276  6.88930458 -1.00303154
#  -1.00256038 -1.00299407]
# ratios err: [1.52100356e+01 0.00000000e+00 2.47923564e-01 1.24859929e-01
#  8.66493668e+02 2.31113880e-01 1.16091393e+00 1.37280559e-01]
# ratios err normed: [-4.62522875e-02 -0.00000000e+00 -7.53912238e-04 -3.79687300e-04
#  -2.63492574e+00 -7.02795569e-04 -3.53023007e-03 -4.17457267e-04]
# mean: -328.84936950597347
# ConstantKernel(log_constant=1.9142918073777966, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.58572405 0.58859411 0.80917054 1.37698378 0.11448078 1.03841924
#  0.88337295 1.2166858 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r'
#  'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 2595.3928377724496
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [-4.44135889  0.          0.08205281 37.12861761  3.41179986  0.82245427
#   0.53561794  1.03658662]
# ratios normed: [-1.92106706 -1.         -0.98298355  6.69988361 -0.29244708 -0.82943609
#  -0.88892137 -0.78502845]
# ratios err: [1.62924498 0.         0.01636259 4.66369975 1.13949705 0.19066775
#  0.73850624 0.14452905]
# ratios err normed: [0.33787945 0.         0.00339334 0.96717701 0.23631353 0.03954145
#  0.15315442 0.02997302]
# mean: 4.8219712781241
# ConstantKernel(log_constant=1.8856507658012045, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [ 0.75424302 -1.50482963  0.73317443  0.40765362  0.85787938  0.97445225
#   0.89912458  1.29859024]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r'
#  'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 36.12861761031371
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 1.60638356 -0.          0.28289102 -3.10687261 -0.54113848  1.01330388
#   0.83131332  1.01922219]
# ratios normed: [ 10.62884355  -1.           1.0478891  -23.49110138  -4.91737993
#    6.33545377   5.01799766   6.37829722]
# ratios err: [0.58927738 0.         0.05641279 0.3902521  0.18073326 0.234912
#  1.14620893 0.14210797]
# ratios err normed: [4.26586445 0.         0.4083804  2.82509155 1.30835425 1.70056203
#  8.2975727  1.0287402 ]
# mean: 0.13813785965070122
# ConstantKernel(log_constant=4.601518283958933, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.24862191 0.29103404 0.67553379 1.8731508  0.66271767 0.97436383
#  0.97963358 1.2950893 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r'
#  'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 4.106872605465297
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ -0.70756482   0.           1.23434183   1.98969173 -24.05058706
#    0.98249017   0.79511841   1.00937346]
# ratios normed: [-0.69805956 -1.         -1.52673296 -1.84906482  9.26315133 -1.41925984
#  -1.33930235 -1.43073179]
# ratios err: [0.2595594  0.         0.24614664 0.24992379 8.03258516 0.22776852
#  1.09630366 0.14073478]
# ratios err normed: [-0.11076226 -0.         -0.10503861 -0.10665044 -3.42775986 -0.09719608
#  -0.46782768 -0.06005601]
# mean: -2.3433920341634416
# ConstantKernel(log_constant=2.514649867001958, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.54363895 0.33336505 0.63490122 1.26046021 0.27003146 0.97331809
#  0.96004965 1.29708794]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r'
#  'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57988.990003_spec_extended.txt
# self.spec_file 57988.990003_spec_extended.txt
# [DEBUG] Starting mangling for: 57988.990003_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [ -2.54094581   0.           0.91045962   1.16195942 -12.78695514
#    1.82532976   0.93445551]
# ratios normed: [ 0.69465841 -1.         -1.60722194 -1.77495722  7.52813196 -2.21738544
#  -1.62322576]
# ratios err: [ 7.92327677  0.          0.73192492  0.2998564  19.78988074  0.95677351
#   0.18373005]
# ratios err normed: [ -5.28435026  -0.          -0.48815001  -0.19998623 -13.19866321
#   -0.63811053  -0.12253692]
# mean: -1.4993852353489352
# ConstantKernel(log_constant=2.3229564197869252, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.58016012 1.04710025 0.70148777 1.29241231 0.63085561 0.98365809
#  1.16082091]
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 13.786955143400482
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [ -5.1137984    0.           1.10818778   0.99225515 -19.54197475
#    6.39202332   1.24379521]
# ratios normed: [ 1.3993137  -1.         -1.51994426 -1.46555049  8.1687869  -3.99903671
#  -1.58356913]
# ratios err: [15.94604652  0.          0.89087998  0.25606235 30.24436587  3.3504733
#   0.24455156]
# ratios err normed: [ -7.48163398  -0.          -0.41798686  -0.12014042 -14.19018032
#   -1.57198932  -0.11473974]
# mean: -2.131358812195359
# ConstantKernel(log_constant=2.5828671323154704, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.59900303 1.06214689 0.70331744 1.29183632 0.64366867 0.94554686
#  1.19326038]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 20.541974745854322
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [ -8.66448823   0.           1.04013308   0.98790738 -24.21666894
#    7.88839873   1.31040998]
# ratios normed: [ 1.80089383 -1.         -1.33623478 -1.31935224  6.82831215 -3.55001412
#  -1.42360485]
# ratios err: [27.01794668  0.          0.83617033  0.25494036 37.47921104  4.13482054
#   0.25764917]
# ratios err normed: [ -8.73385687  -0.          -0.27030152  -0.08241236 -12.1155789
#   -1.33662751  -0.08328801]
# mean: -3.09347257282582
# ConstantKernel(log_constant=2.2885518019435414, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.62459391 1.05999283 0.70786436 1.2884719  0.6570579  0.93289641
#  1.2075757 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 25.216668942787138
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [-18.41550627   0.           1.00523575   0.992543   -35.15219511
#    6.39586552   1.25686786]
# ratios normed: [ 1.93526398 -1.         -1.16022542 -1.15820232  4.60293976 -2.01944271
#  -1.20033329]
# ratios err: [57.42395318  0.          0.80811612  0.25613664 54.40370607  3.35248724
#   0.24712187]
# ratios err normed: [-9.15285516 -0.         -0.12880635 -0.04082585 -8.67145528 -0.53435593
#  -0.03938898]
# mean: -6.273884177955248
# ConstantKernel(log_constant=1.584524583515348, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.66360659 1.04220525 0.71801242 1.28428583 0.67224782 0.92601164
#  1.21463584]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 36.15219510748604
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [ -82.31497285    0.            0.95995867    1.00954564 -100.6244644
#     2.92300821    1.21407986]
# ratios normed: [ 2.25847164 -1.         -1.03800035 -1.03996327  2.9832603  -1.11570847
#  -1.04805984]
# ratios err: [2.56677773e+02 0.00000000e+00 7.71717557e-01 2.60524353e-01
#  1.55732630e+02 1.53213787e+00 2.38709010e-01]
# ratios err normed: [-1.01606939e+01 -0.00000000e+00 -3.05487530e-02 -1.03129624e-02
#  -6.16473941e+00 -6.06502998e-02 -9.44939313e-03]
# mean: -25.26183498080893
# ConstantKernel(log_constant=1.0246447854834821, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70822129 0.9955654  0.74928127 1.27980056 0.6976369  0.92121145
#  1.22009446]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_I
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 101.62446440285606
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(22777), Im chopping a 4 th of them
# ratios: [232.25808631   0.           1.09681158   1.06840723 117.64357244
#    1.14727049   1.20853853]
# ratios normed: [ 3.58719677 -1.         -0.9783375  -0.9788985   1.32351099 -0.97734092
#  -0.97613085]
# ratios err: [7.24236265e+02 0.00000000e+00 8.81734571e-01 2.75714233e-01
#  1.82072451e+02 6.01358751e-01 2.37619490e-01]
# ratios err normed: [1.43039767e+01 0.00000000e+00 1.74146358e-02 5.44547431e-03
#  3.59600897e+00 1.18770931e-02 4.69308680e-03]
# mean: 50.6318123688315
# ConstantKernel(log_constant=1.0215808297851814, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.58923175 0.95800459 0.86450007 1.27302594 0.72072668 0.91515798
#  1.22573086]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_I' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_I
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57984.969003_spec_extended.txt
# self.spec_file 57984.969003_spec_extended.txt
# [DEBUG] Starting mangling for: 57984.969003_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [1.24328469 0.         0.26829094 1.93725677 0.94725151 1.09334048
#  1.00071775]
# ratios normed: [ 0.34095566 -1.         -0.71063244  1.08944536  0.02166647  0.17923201
#   0.07933295]
# ratios err: [0.2425414  0.         0.06773372 0.35645556 0.13741996 0.02841898
#  0.08769282]
# ratios err normed: [0.26159517 0.         0.0730548  0.38445828 0.14821551 0.03065155
#  0.09458186]
# mean: 0.9271631638325831
# ConstantKernel(log_constant=-0.8996346182972444, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57515104 0.46151526 0.71183409 0.60610174 0.97049962 0.82856937
#  1.1529547 ]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 1.0
# [DEBUG] Calling calculate_ratios4mangling...
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [4.69924986 0.         0.47469622 6.20495629 0.83432607 1.05592983
#  0.99339483]
# ratios normed: [ 1.30637171 -1.         -0.76702113  2.04536598 -0.59051634 -0.48175416
#  -0.51244607]
# ratios err: [0.91673506 0.         0.11984355 1.14171295 0.12103761 0.02744658
#  0.08705111]
# ratios err normed: [0.44992964 0.         0.0588187  0.56034783 0.05940474 0.01347066
#  0.04272431]
# mean: 2.0375075868161425
# ConstantKernel(log_constant=0.17297420245784234, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.58669184 0.68599601 0.73677582 0.61475478 0.96888297 0.83333621
#  1.15100313]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 5.2049562926124935
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [ 5.10678251  0.          1.0104471  10.13996981  0.9202722   1.05583203
#   0.99590417]
# ratios normed: [ 0.85901977 -1.         -0.63216739  2.69124872 -0.66499372 -0.61564593
#  -0.63746145]
# ratios err: [0.996237   0.         0.25510119 1.86575607 0.13350601 0.02744404
#  0.087271  ]
# ratios err normed: [0.36265971 0.         0.09286437 0.67919036 0.04860013 0.00999044
#  0.03176922]
# mean: 2.7470296880563296
# ConstantKernel(log_constant=0.41569488027086526, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.56840057 1.0998374  0.79170395 0.58634485 0.96495365 0.83804948
#  1.15788531]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 9.139969808384725
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [1.02407467 0.         0.7198069  2.14972189 1.30737523 0.96492673
#  1.01941532]
# ratios normed: [-0.00233783 -1.         -0.29875805  1.09427717  0.27365596 -0.05996025
#  -0.00687701]
# ratios err: [0.19977766 0.         0.1817251  0.39554917 0.18966394 0.02508115
#  0.08933128]
# ratios err normed: [0.19462508 0.         0.17703812 0.38534734 0.18477221 0.02443427
#  0.08702729]
# mean: 1.0264743917632093
# ConstantKernel(log_constant=-1.0850329843485669, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.56519884 1.83238327 0.76618347 0.5826078  0.94096215 0.83570349
#  1.220339  ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 1.1497218892228287
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [0.91505068 0.         0.74489112 1.94883354 1.20501042 0.99120669
#  1.01587977]
# ratios normed: [-0.06091853 -1.         -0.23554676  1.00001325  0.23665606  0.01723747
#   0.04255851]
# ratios err: [0.17850914 0.         0.18805795 0.35858568 0.17481364 0.02576424
#  0.08902146]
# ratios err normed: [0.18319709 0.         0.19299667 0.36800276 0.17940455 0.02644085
#  0.09135932]
# mean: 0.9744103179969336
# ConstantKernel(log_constant=-1.1957522645584708, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.56434867 2.75580317 0.76445032 0.5816483  0.9418108  0.83652064
#  1.21669013]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 1.0
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23423), Im chopping a 4 th of them
# ratios: [0.87993502 0.         0.75931838 1.88671646 1.13529301 0.99660005
#  0.99416043]
# ratios normed: [-0.07403435 -1.         -0.20096061  0.98541324  0.19468178  0.04873359
#   0.04616635]
# ratios err: [0.17165873 0.         0.19170031 0.34715613 0.16469957 0.02590443
#  0.0871182 ]
# ratios err normed: [0.18063844 0.         0.20172842 0.36531635 0.17331524 0.02725953
#  0.09167547]
# mean: 0.950289051190656
# ConstantKernel(log_constant=-1.223537817217427, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.56395783 3.60015745 0.76422247 0.58119725 0.94224884 0.83711581
#  1.2155722 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57991.000003_spec_extended.txt
# self.spec_file 57991.000003_spec_extended.txt
# [DEBUG] Starting mangling for: 57991.000003_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [4.17780345 0.99444595]
# ratios normed: [ 0.61546868 -0.61546868]
# ratios err: [16.71528652  0.07058968]
# ratios err normed: [6.46344955 0.02729555]
# mean: 2.586124697948815
# ConstantKernel(log_constant=-0.9707424456036129, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.55339935 1.11472303]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 3.1778034478283717
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [2.26332697 0.97080091]
# ratios normed: [ 0.39965212 -0.39965212]
# ratios err: [9.0555143  0.06891127]
# ratios err normed: [5.59997293 0.04261505]
# mean: 1.6170639421593345
# ConstantKernel(log_constant=-1.8343216233911808, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.55136283 1.11559505]
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 1.2633269739057176
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [1.71679298 0.98136473]
# ratios normed: [ 0.27256681 -0.27256681]
# ratios err: [6.86884555 0.06966113]
# ratios err normed: [5.09150781 0.05163607]
# mean: 1.3490788585318327
# ConstantKernel(log_constant=-2.5997430208957075, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.55024604 1.11598571]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 0.716792983179716
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [1.45146637 0.98096391]
# ratios normed: [ 0.19342896 -0.19342896]
# ratios err: [5.80728045 0.06963268]
# ratios err normed: [4.77487926 0.05725358]
# mean: 1.2162151410572815
# ConstantKernel(log_constant=-3.2856899135161983, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.54956497 1.11620774]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 0.45146637303292425
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [1.30199777 0.97725841]
# ratios normed: [ 0.14247603 -0.14247603]
# ratios err: [5.20926035 0.06936964]
# ratios err normed: [4.57101785 0.06087042]
# mean: 1.1396280906006875
# ConstantKernel(log_constant=-3.8971630397813812, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.54912875 1.11634506]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 0.30199777403746175
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(20049), Im chopping a 4 th of them
# ratios: [1.21090281 0.97259318]
# ratios normed: [ 0.10914132 -0.10914132]
# ratios err: [4.8447917  0.06903849]
# ratios err normed: [4.43764652 0.06323665]
# mean: 1.0917479969274628
# ConstantKernel(log_constant=-4.430223488748315, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.54884336 1.11643305]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57987.980003_spec_extended.txt
# self.spec_file 57987.980003_spec_extended.txt
# [DEBUG] Starting mangling for: 57987.980003_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(23459), Im chopping a 4 th of them
# ratios: [-1.98132367  0.93010503  1.00034129 -4.53512745  2.64200237  0.97979178]
# ratios normed: [ 11.32919592  -6.78777073  -7.22483033  27.22076755 -17.44040563
#   -7.09695678]
# ratios err: [4.18359843 0.35438312 0.0820015  6.52482475 1.14173474 0.10193031]
# ratios err normed: [-26.03330561  -2.20522219  -0.51027125 -40.60207008  -7.10468034
#   -0.63428239]
# mean: -0.1607017754003767
# ConstantKernel(log_constant=5.395237927101658, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57846077 0.69879318 1.29157645 0.62453811 0.98443904 1.15980562]
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 5.535127448654226
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23459), Im chopping a 4 th of them
# ratios: [-3.59749282  1.01087397  1.00769219 -6.60174392  1.90354549  0.94035313]
# ratios normed: [ 3.04457172 -2.13650047 -2.13292327  6.42217652 -3.14010886 -2.05721564]
# ratios err: [7.59616691 0.38515722 0.08260407 9.49812824 0.82261244 0.0978274 ]
# ratios err normed: [ -8.54018156  -0.43302269  -0.09286971 -10.67850939  -0.92484271
#   -0.10998491]
# mean: -0.8894619926265225
# ConstantKernel(log_constant=2.508517159428387, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.59183137 0.70448435 1.29174876 0.63587323 0.98240897 1.1556944 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 7.601743916504894
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23459), Im chopping a 4 th of them
# ratios: [-6.12050784  1.01499359  1.0093669  -8.86151021  1.34014603  0.92634149]
# ratios normed: [ 2.43489505 -1.56962535 -1.5664676   3.97317516 -1.75210442 -1.51987284]
# ratios err: [12.92355577  0.38672686  0.08274136 12.74932222  0.57914077  0.09636973]
# ratios err normed: [-7.25283897 -0.21703529 -0.04643534 -7.15505721 -0.32502005 -0.05408373]
# mean: -1.781861673029449
# ConstantKernel(log_constant=1.6743595665460116, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.60862128 0.71129414 1.29208665 0.6469024  0.97958578 1.15192582]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# ...
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57983.969001_spec_extended.txt
# self.spec_file 57983.969001_spec_extended.txt
# [DEBUG] Starting mangling for: 57983.969001_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: [1.04157372 0.         0.19177021 1.60213406 0.97891424 1.52915112
#  1.00244939]
# ratios normed: [ 0.14891655 -1.         -0.78846628  0.76724728  0.07979948  0.68674285
#   0.10576012]
# ratios err: [0.05697358 0.         0.05440619 0.06148755 0.07467895 0.12791375
#  0.03444249]
# ratios err normed: [0.06284518 0.         0.0600132  0.06782435 0.08237523 0.14109633
#  0.03799207]
# mean: 0.9065703913676302
# ConstantKernel(log_constant=-0.9446562175254841, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.61215249 0.49284373 0.76122795 0.64377418 1.03183446 0.87144676
#  1.22766262]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 1.0
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [1.10589543 0.         0.26865451 1.61513346 0.98844777 2.0191513
#  1.00058791]
# ratios normed: [ 1.06231984e-01 -1.00000000e+00 -7.31263729e-01  6.15624982e-01
#  -1.12514220e-02  1.01976578e+00  8.92408210e-04]
# ratios err: [0.06049194 0.         0.07621866 0.06198644 0.07540624 0.16890235
#  0.03437853]
# ratios err normed: [0.06051035 0.         0.07624185 0.06200531 0.07542919 0.16895375
#  0.03438899]
# mean: 0.9996957685216398
# ConstantKernel(log_constant=-0.8590076105474994, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.61959255 0.83804309 0.75335548 0.64466748 1.03285303 0.87861769
#  1.22714324]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 1.0191513011076925
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.85563039 0.         0.57547182 1.38802524 1.12960417 9.30980018
#  0.9936726 ]
# ratios normed: [-0.57975534 -1.         -0.71735581 -0.3182685  -0.44519255  3.57252783
#  -0.51195562]
# ratios err: [0.04680257 0.         0.16326429 0.05327036 0.08617471 0.77876637
#  0.03414093]
# ratios err normed: [0.02298718 0.         0.0801876  0.02616385 0.04232489 0.38249273
#  0.01676839]
# mean: 2.036029200138082
# ConstantKernel(log_constant=0.7737563555371113, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.61440681 0.95256281 0.71143521 0.63721265 1.04153658 0.90529737
#  1.22522525]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 8.309800180103649
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 0.98228142  0.          0.59699353  1.33006204  1.23062003 32.61614677
#   0.96271109]
# ratios normed: [-0.81770451 -1.         -0.88920769 -0.75316207 -0.77161689  5.0530276
#  -0.82133644]
# ratios err: [0.05373032 0.         0.16937011 0.05104582 0.09388096 2.72834622
#  0.03307714]
# ratios err normed: [0.00997148 0.         0.03143234 0.00947328 0.01742278 0.50633679
#  0.00613858]
# mean: 5.3884021251289775
# ConstantKernel(log_constant=1.4495929897132847, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.63237904 0.44062234 0.70116324 0.64645971 1.06965187 0.89003569
#  1.2106436 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 31.616146770954927
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [ 1.10158005 -0.          0.43083793  1.34525307  0.6472111   2.55646699
#   0.97691202]
# ratios normed: [ 0.09248726 -1.         -0.57271834  0.33414892 -0.35813119  1.53536508
#  -0.03115173]
# ratios err: [0.06025589 0.         0.12223092 0.05162883 0.04937414 0.2138489
#  0.03356506]
# ratios err normed: [0.05975852 0.         0.12122199 0.05120267 0.04896659 0.21208372
#  0.03328801]
# mean: 1.0083230242207146
# ConstantKernel(log_constant=-0.57605263352143, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.64281065 0.22912421 0.73511213 0.6524487  1.02400684 0.89401224
#  1.27210127]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 1.5564669888401141
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.92339518 0.         0.39391115 1.14042804 0.90986194 2.23012205
#  1.01869356]
# ratios normed: [-0.02307076 -1.         -0.58325175  0.20654463 -0.03738859  1.35941391
#   0.07775257]
# ratios err: [0.05050927 0.         0.11175461 0.04376795 0.06941112 0.18655009
#  0.03500061]
# ratios err normed: [0.05343756 0.         0.11823361 0.04630541 0.07343525 0.19736537
#  0.03702978]
# mean: 0.9452017043369351
# ConstantKernel(log_constant=-0.7706995084496695, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [ 0.64236611 -2.03065939  0.73550025  0.6516617   1.02119283  0.89384991
#   1.27893598]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_U' 'Bessell_V' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_U
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# 57986.974003_spec_extended.txt
# self.spec_file 57986.974003_spec_extended.txt
# [DEBUG] Starting mangling for: 57986.974003_spec_extended.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# [DEBUG] Calling GP_interpolation_mangle (initial)
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.79263144 0.90640729 0.99725217 1.38597453 1.70887693 0.19375123
#  1.01569221]
# ratios normed: [-0.20743488 -0.09366856 -0.00283128  0.38585855  0.70873393 -0.80626498
#   0.01560722]
# ratios err: [0.14136625 0.15823301 0.01829011 0.17047666 0.55894252 5.13215508
#  0.15394285]
# ratios err normed: [0.14135442 0.15821976 0.01828858 0.17046239 0.55889574 5.13172563
#  0.15392997]
# mean: 1.0000836864883245
# ConstantKernel(log_constant=-1.6433578406132636, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57648238 0.70876413 1.29416391 0.61494052 0.98200406 0.82452183
#  1.15334445]
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   np.isinf(fitted_phot_err / fitted_phot)
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 0.8062487709772196
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.80046772 0.8886977  0.99936581 1.38421716 1.61119469 0.18614232
#  0.98649402]
# ratios normed: [-0.18278872 -0.09271321  0.02026977  0.41317114  0.6448964  -0.8099641
#   0.00712873]
# ratios err: [0.14276385 0.15514141 0.01832887 0.1702605  0.52699243 4.93060739
#  0.14951744]
# ratios err normed: [0.14575007 0.15838654 0.01871226 0.17382187 0.53801565 5.03374199
#  0.15264493]
# mean: 0.9795113454603257
# ConstantKernel(log_constant=-1.695063697531865, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57712244 0.70926081 1.29405242 0.61553527 0.98196216 0.82483989
#  1.1523639 ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 0.8138576824749633
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.80755209 0.88211862 0.99992226 1.38647951 1.55865944 0.1827114
#  0.97252097]
# ratios normed: [-0.16746769 -0.09059458  0.03085311  0.42936783  0.60687386 -0.81163674
#   0.00260421]
# ratios err: [0.14402735 0.15399289 0.01833908 0.17053877 0.50980911 4.83972788
#  0.14739962]
# ratios err normed: [0.14848259 0.15875639 0.01890637 0.17581409 0.52557917 4.98943643
#  0.15195917]
# mean: 0.969994897288384
# ConstantKernel(log_constant=-1.723872553616804, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57756313 0.70948699 1.2940089  0.61590438 0.98193861 0.82506087
#  1.15184863]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 0.8172886030136569
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.81197365 0.8787598  1.0001887  1.38689249 1.52569149 0.18091542
#  0.96570145]
# ratios normed: [-0.1579686  -0.08871015  0.03721383  0.43823267  0.58216975 -0.81238742
#   0.00144992]
# ratios err: [0.14481594 0.15340654 0.01834396 0.17058957 0.49902589 4.79215549
#  0.14636602]
# ratios err normed: [0.15017676 0.15908536 0.01902302 0.17690447 0.5174989  4.96955217
#  0.15178422]
# mean: 0.9643032860318265
# ConstantKernel(log_constant=-1.7428441283156775, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57790152 0.7095634  1.29399605 0.616158   0.98191245 0.82522477
#  1.15154181]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 0.8190845753294329
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.81480314 0.87692918 1.00032644 1.38606353 1.50258034 0.17993869
#  0.96244278]
# ratios normed: [-0.15163608 -0.08695114  0.04152871  0.44315385  0.56446986 -0.81264985
#   0.00208466]
# ratios err: [0.14532058 0.15308696 0.01834649 0.1704876  0.49146666 4.76628333
#  0.14587212]
# ratios err normed: [0.15130616 0.15939243 0.01910216 0.17750979 0.51170959 4.96260092
#  0.15188043]
# mean: 0.9604405843700651
# ConstantKernel(log_constant=-1.757197132472318, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57818445 0.70955974 1.29399797 0.61634973 0.98188599 0.82535756
#  1.15134116]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 0.820061311786298
# [DEBUG] Calling calculate_ratios4mangling...
# [DEBUG] Calling GP_interpolation_mangle...
# This spectrum has a huge amount of data points(23500), Im chopping a 4 th of them
# ratios: [0.81672583 0.87592317 1.000399   1.38454097 1.48476341 0.17940455
#  0.96099558]
# ratios normed: [-0.14705477 -0.08523219  0.04476377  0.44594131  0.55060833 -0.81263938
#   0.00361293]
# ratios err: [0.14566349 0.15291134 0.01834782 0.17030033 0.48563906 4.75213492
#  0.14565278]
# ratios err normed: [0.15212324 0.15969251 0.01916149 0.17785265 0.50717574 4.96287821
#  0.15211206]
# mean: 0.9575360748533273
# ConstantKernel(log_constant=-1.7691687763954027, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.57843533 0.70951244 1.29400686 0.61650637 0.98186106 0.82547282
#  1.15119681]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'Bessell_V' 'Y' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: Bessell_V
# [DEBUG] Computing band_flux for filter: Y
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum

# %%
color=cycle(plt.cm.gnuplot(np.linspace(0,1,int(len(new_spec.get_spec_list())*1.2))))
fig= plt.figure(1, figsize=(10,6))
plt.title(new_spec.snname, fontsize=15)
mean=1.; a=0
for l in new_spec.get_spec_list()[:]:
    new_spec.create_FINALspec_folder()
    sp = np.genfromtxt(new_spec.FINALspec_path+l.replace('spec_extended', 'FINAL_spec'))
    plt.plot(sp[:,0], sp[:,1], #+mean*a, 
             lw=1.5,color=next(color))
    if mean==1.:
        mean = np.median(sp[:,1])*0.2
    a=a+1
    
plt.hlines(0, 1500, 11000, lw=0.7, linestyle='--')
plt.ylabel('Calibrated Flux, Dust corrected [erg s-1 cm-2 AA-1]')
plt.xlabel('wls [AA]')
plt.ylim(0,.05)
fig.savefig(new_spec.FINALspec_path+'Final_Spec.png', bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ### SECOND: Remangle the "artificial" spectra (i.e. spectra that we extrapolated from the 2dim surface @phases were spectroscopy was too sparse)

# %%
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                        spec_file=None, verbose=True)
for f in new_spec.get_FLAGGED_spec_list():
    new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                    spec_file=f, verbose=True)
    new_spec.load_extended_spec()
    result = new_spec.mangle_iteration_function()
    new_spec.save_FINAL_spectrum()
# Out:
# Choose one spec_file from this list:
# ['56467.00_spec_extended.txt', '56462.34_spec_extended.txt', '56544.26_spec_extended.txt', '56468.00_spec_extended.txt', '56508.00_spec_extended.txt', '56460.91_spec_extended.txt', '56510.00_spec_extended.txt', '56469.00_spec_extended.txt', '56463.00_spec_extended.txt', '56471.00_spec_extended.txt', '56474.00_spec_extended.txt', '56482.34_spec_extended.txt', '56512.42_spec_extended.txt', '56474.10_spec_extended.txt', '56478.00_spec_extended.txt', '56484.00_spec_extended.txt', '56477.00_spec_extended.txt', '56506.43_spec_extended.txt', '56460.00_spec_extended.txt', '56465.00_spec_extended.txt', '56496.00_spec_extended.txt', '56470.16_spec_extended.txt', '56494.93_spec_extended.txt', '56539.00_spec_extended.txt', '56461.00_spec_extended.txt']
# self.spec_file 56640.48_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56628.52_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56514.85_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56459.61_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56477.33_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56540.78_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56602.59_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56501.83_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56498.90_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.67_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56636.49_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56574.68_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56632.51_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56542.51_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56536.79_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56504.58_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56506.88_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56584.65_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56652.45_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56468.17_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56524.82_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56618.55_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56467.12_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56474.97_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56491.60_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56470.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56486.36_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56498.51_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56648.46_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56512.86_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56564.71_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.87_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56470.98_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56499.80_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56612.57_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56480.28_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56494.91_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.06_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56489.58_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56464.93_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56558.72_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56518.84_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56624.53_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56460.45_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56476.23_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56487.50_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56464.96_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56486.19_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56471.10_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56532.80_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56462.95_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56468.80_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56499.79_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56536.98_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56644.47_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56512.68_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56480.95_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56588.64_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56478.96_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56492.92_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56592.62_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56578.66_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56552.74_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56524.83_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.23_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56505.95_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56484.94_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56510.65_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56475.29_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56475.50_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56534.95_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56473.25_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56474.60_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56468.99_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56479.30_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56568.69_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56474.21_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56463.78_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56494.46_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56465.08_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56461.28_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56463.04_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56532.93_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56482.25_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56522.80_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56598.61_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56464.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56483.46_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56477.25_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56497.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56500.53_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56544.76_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56476.54_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56530.90_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56622.54_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56502.89_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56656.44_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56493.67_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56507.96_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56487.54_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.07_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56480.50_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56570.69_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56658.43_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56462.11_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56606.58_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56528.88_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56526.85_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56485.45_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56518.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56503.88_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56566.70_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.37_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56486.94_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56586.64_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56508.63_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56476.96_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56483.40_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56528.81_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56614.56_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56482.31_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56478.26_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56469.05_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56489.55_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56600.60_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56488.93_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56654.44_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56502.56_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56500.89_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56492.74_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56620.54_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56554.74_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56475.20_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56590.63_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56616.55_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56495.70_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56522.83_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.98_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56503.90_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56470.74_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56478.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56464.47_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56530.81_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56546.76_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56469.17_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56626.52_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56540.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56491.62_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56480.41_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56460.68_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56462.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56481.35_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56492.43_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56478.47_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56638.49_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56508.87_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56634.50_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56630.51_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56534.79_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56580.66_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56462.93_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56506.60_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56458.78_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56516.73_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56608.58_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56516.85_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56560.72_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56642.48_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56556.73_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56464.28_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56520.84_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56496.48_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56510.86_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56520.78_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56542.77_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56490.41_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56470.11_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56471.21_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56594.62_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56576.67_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56550.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56526.82_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56462.57_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56650.45_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56484.33_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56504.88_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56493.65_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56485.50_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56505.92_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56604.59_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56488.38_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56548.75_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56470.03_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56490.56_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56538.78_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56572.68_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.98_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56596.61_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56496.91_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56610.57_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56495.71_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56490.92_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56481.42_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56514.70_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56473.15_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56582.65_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56479.38_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56482.95_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56468.26_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56562.71_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56501.85_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56646.47_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56472.18_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56476.00_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56488.37_spec_extended_FL.txt
# ITERATION 5 5
# self.spec_file 56466.99_spec_extended_FL.txt
# ITERATION 5 5

# %%
new_spec.create_FINALspec_folder()
color=cycle(plt.cm.gnuplot(np.linspace(0,1,int(len(new_spec.get_FLAGGED_spec_list())*1.2))))
fig= plt.figure(1, figsize=(10,6))
plt.title(snname+' ARTIFICIAL', fontsize=15)
mean=1.; a=0
for l in new_spec.get_FLAGGED_spec_list()[:]:
    sp = np.genfromtxt(new_spec.FINALspec_path+l.replace('spec_extended', 'FINAL_spec'))
    plt.plot(sp[:,0], sp[:,1],#+mean*a,
             lw=1.5,color=next(color))
    if mean==1.:
        mean = np.median(sp[:,1])*0.2
    
plt.hlines(0, 1500, 11000, lw=0.7, linestyle='--')
plt.ylabel('Calibrated Flux, Dust corrected [erg s-1 cm-2 AA-1]')
plt.xlabel('wls [AA]')
fig.savefig(new_spec.FINALspec_path+'Final_Spec_FL.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
mu_fill_conv, std_fill_conv, y_data_conv = GP2dim.transform_back_andPlot(spec_class, x1_fill, x2_fill, 
                                                                         mu_fill, std_fill, y_data_nonan)

# %%
#try for KN
new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                        spec_file=None, verbose=True)
for f in new_spec.get_FLAGGED_spec_list():
    new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
                    spec_file=f, verbose=True)
    new_spec.load_extended_spec()
    result = new_spec.mangle_iteration_function()
    new_spec.save_FINAL_spectrum()
# Out:
# Choose one spec_file from this list:
# ['57987.980002_spec_extended.txt', '57990.000001_spec_extended.txt', '57985.974001_spec_extended.txt', '57988.990003_spec_extended.txt', '57984.969003_spec_extended.txt', '57991.000003_spec_extended.txt', '57987.980003_spec_extended.txt', '57988.990002_spec_extended.txt', '57984.969002_spec_extended.txt', '57990.000003_spec_extended.txt', '57985.974003_spec_extended.txt', '57988.990001_spec_extended.txt', '57984.969001_spec_extended.txt', '57991.000001_spec_extended.txt', '57987.980001_spec_extended.txt', '57990.000002_spec_extended.txt', '57985.974002_spec_extended.txt', '57983.969002_spec_extended.txt', '57986.974001_spec_extended.txt', '57983.969003_spec_extended.txt', '57986.974002_spec_extended.txt', '57983.969001_spec_extended.txt', '57986.974003_spec_extended.txt']
# self.spec_file 57988.970574_spec_extended_FL.txt
# [DEBUG] Starting mangling for: 57988.970574_spec_extended_FL.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=2.1499804160290285e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=5.852193048936547e-18, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=5.641318933581821e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=4.128524066846946e-17, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=3.80976974398265e-18, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=7.264313254109986e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: [-2.75471008  2.35783332  0.96415128]
# ratios normed: [-15.56813215  11.46927133   4.09886082]
# ratios err: [8.3603613  1.23115061 0.18874485]
# ratios err normed: [44.21330909  6.51087202  0.99816671]
# mean: 0.1890915081980785
# ConstantKernel(log_constant=4.869357361537683, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.74293476 1.27070304 1.499463  ]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 3.7547100805622566
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=2.862739157636447e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=3.548775884531576e-18, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=6.632241336292242e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=2.6338209219509715e-17, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=3.603941321194867e-18, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=1.008866866934315e-17, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [-3.26482486  1.57290669  0.9789814 ]
# ratios normed: [12.73820938 -7.61870772 -5.11950166]
# ratios err: [9.90852561 0.82129853 0.19164803]
# ratios err normed: [-41.69454884  -3.45598052  -0.80644472]
# mean: -0.23764558883502904
# ConstantKernel(log_constant=4.408814540907325, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.75100288 1.26802191 1.48226323]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 4.264824856679578
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=3.402133349076213e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=7.867989795921112e-19, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=5.400292271722905e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=1.682026307014145e-17, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=2.082881126535588e-18, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=1.0475366585168615e-17, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [-6.8639437   1.2488791   1.00526471]
# ratios normed: [ 3.46696854 -1.81275487 -1.65421368]
# ratios err: [20.83161118  0.65210643  0.19679332]
# ratios err normed: [-13.55695149  -0.42438269  -0.12807063]
# mean: -1.5365999641624206
# ConstantKernel(log_constant=1.7941108124677165, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.76636417 1.26752349 1.47013438]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 7.863943703799871
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=3.891676836305369e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=-5.822161774607263e-19, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=1.3940721405801324e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=7.572099220283532e-18, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=-2.8915648835734733e-19, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=6.617858064417848e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [23.2100787   1.09119228  1.03606189]
# ratios normed: [ 1.74812809 -0.87080026 -0.87732783]
# ratios err: [70.44104028  0.56976972  0.20282226]
# ratios err normed: [8.34038539 0.06746208 0.02401463]
# mean: 8.445777622966848
# ConstantKernel(log_constant=0.42394856895082567, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.72729005 1.27083511 1.45688472]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 22.210078703143914
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=3.9212908625433816e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=-3.726090755042833e-18, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=4.518743211339845e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=1.8280257880907486e-17, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=-1.5383190734003532e-18, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=1.7485352874506538e-17, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [4.19878444 0.932825   0.91237285]
# ratios normed: [ 1.08411487 -0.5369816  -0.54713326]
# ratios err: [12.74303063  0.48707771  0.17860856]
# ratios err normed: [6.32514956 0.24176662 0.08865441]
# mean: 2.014660760307372
# ConstantKernel(log_constant=-0.5315902295273749, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.72433059 1.25633935 1.474371  ]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 3.1987844389277544
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=3.6846414602436157e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=-6.409650429670679e-18, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=5.821331024743459e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=2.0037586631380587e-17, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=-2.4149820677004232e-18, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=2.103914349880276e-17, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [2.62477384 0.94911178 0.96862766]
# ratios normed: [ 0.73347243 -0.37318062 -0.3602918 ]
# ratios err: [7.96601346 0.49558191 0.18962116]
# ratios err normed: [5.26097316 0.32729585 0.125231  ]
# mean: 1.5141710910383421
# ConstantKernel(log_constant=-1.3129748039249232, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.72290195 1.25312741 1.47773189]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_i' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# self.spec_file 57972.252715_spec_extended_FL.txt
# [DEBUG] Starting mangling for: 57972.252715_spec_extended_FL.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=1.011243612195311e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=3.3819560202159584e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=3.8349069640709564e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=7.71846887344351e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: [0.36343209 1.00958291 0.57904747 1.47493857 0.5081907 ]
# ratios normed: [-0.53822823  0.28276203 -0.26427032  0.87403647 -0.35429995]
# ratios err: [0.97182939 2.11916853 0.74272351 5.61565528 0.62297195]
# ratios err normed: [1.23479294 2.69258612 0.94369418 7.13517366 0.79153952]
# mean: 0.7870383473321552
# ConstantKernel(log_constant=-1.3250479963575252, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70548509 0.74648526 1.25488149 1.05105171 1.48050582]
# [DEBUG] Applying initial mangling mask
# [DEBUG] Iteration 0 - max(ratios-1): 0.6365679096182438
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=6.8427383474690396e-18, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=2.4168086178587784e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=2.6645449160422406e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=5.383544158344164e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.51488559 1.43546886 0.85394496 2.14307698 0.74684242]
# ratios normed: [-0.54788742  0.26046162 -0.25016496  0.88180069 -0.34420994]
# ratios err: [1.37682103 3.01312592 1.0953247  8.15951378 0.91552617]
# ratios err normed: [1.20896393 2.64577638 0.96178663 7.16473501 0.80390849]
# mean: 1.138843762622752
# ConstantKernel(log_constant=-1.326776168660339, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70527768 0.74619494 1.25467816 1.05081971 1.48116078]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 0
# [DEBUG] Iteration 1 - max(ratios-1): 1.1430769818179982
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=6.745982322154244e-18, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=2.493450996620137e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=2.6815387566028277e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=5.46678888402612e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.50498782 1.41237145 0.86496216 2.14517277 0.75306919]
# ratios normed: [-0.55551256  0.24316142 -0.23866517  0.88816903 -0.33715273]
# ratios err: [1.35035407 2.96464322 1.10945606 8.16749326 0.92315933]
# ratios err normed: [1.18857408 2.60946232 0.97653699 7.18898171 0.81255966]
# mean: 1.1361126766648835
# ConstantKernel(log_constant=-1.3263672565034834, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70509028 0.74594304 1.25451842 1.05063812 1.48180186]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 1
# [DEBUG] Iteration 2 - max(ratios-1): 1.1451727738240343
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=6.66551311660741e-18, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=2.5606845945123862e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=2.6927680907654065e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=5.561051032993571e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.49738717 1.39512434 0.87458746 2.14835778 0.75744502]
# ratios normed: [-0.56161134  0.22963907 -0.22915335  0.89352634 -0.33240072]
# ratios err: [1.33002968 2.92844062 1.1218021  8.17961981 0.9285235 ]
# ratios err normed: [1.17226574 2.5810782  0.98873746 7.20937902 0.81838496]
# mean: 1.134580355501705
# ConstantKernel(log_constant=-1.32461075266161, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70491777 0.7457202  1.25439057 1.05049505 1.48243486]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [ERROR] band_flux failed for filter Bessell_B: 4
# [DEBUG] Finished iteration 2
# [DEBUG] Iteration 3 - max(ratios-1): 1.148357784802895
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=6.597681280958265e-18, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=2.6207114073328016e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=2.699761128448548e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=5.665001388808526e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.49146327 1.38215651 0.88306436 2.15216331 0.76034911]
# ratios normed: [-0.56654945  0.21900563 -0.22117327  0.89812021 -0.32940311]
# ratios err: [1.31418898 2.90122045 1.13267511 8.19410891 0.93208352]
# ratios err normed: [1.15906105 2.55875803 0.99897322 7.22686964 0.82205962]
# mean: 1.1338393131118856
# ConstantKernel(log_constant=-1.322016609162078, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.7047565  0.74551967 1.25428606 1.05038175 1.48306351]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 3
# [DEBUG] Iteration 4 - max(ratios-1): 1.152163312539726
# [DEBUG] Calling calculate_ratios4mangling...
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=6.539643702316596e-18, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=2.675218827000848e-17, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=2.7036174927765243e-18, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=5.777435759473834e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle...
# ratios: [0.48678461 1.37237264 0.89060168 2.15629468 0.7620981 ]
# ratios normed: [-0.5705967   0.21059978 -0.21438087  0.90211447 -0.32773667]
# ratios err: [1.30167808 2.88068358 1.14234296 8.20983861 0.93422754]
# ratios err normed: [1.14823857 2.54111369 1.00768559 7.24207734 0.82410245]
# mean: 1.133630341192607
# ConstantKernel(log_constant=-1.318924447681157, ndim=1, axes=array([0])) * Matern32Kernel(metric=Metric(0.3, ndim=1, axes=array([0]), bounds=[(None, None)]), block=None)
# wls_eff_normedT: [0.70460379 0.74533642 1.25419849 1.05029166 1.48369026]
# [DEBUG] Applying mangling mask to spectrum...
# [DEBUG] Saving mangled spectrum and errors...
# [DEBUG] Calculating band fluxes...
# [DEBUG] used_filters = ['Bessell_B' 'sdss_g' 'sdss_i' 'sdss_r' 'sdss_z']
# [DEBUG] Computing band_flux for filter: Bessell_B
# [DEBUG] Computing band_flux for filter: sdss_g
# [DEBUG] Computing band_flux for filter: sdss_i
# [DEBUG] Computing band_flux for filter: sdss_r
# [DEBUG] Computing band_flux for filter: sdss_z
# [DEBUG] Finished iteration 4
# skipping plotting for now
# [DEBUG] Saving final mangled spectrum
# self.spec_file 57996.956858_spec_extended_FL.txt
# [DEBUG] Starting mangling for: 57996.956858_spec_extended_FL.txt
# [DEBUG] Calling calculate_ratios4mangling (initial)
# Skipping Bessell_B due to bad values: fitted_phot=nan, raw_phot=4.740590696503366e-18, fitted_phot_err=nan
# Skipping Bessell_I due to bad values: fitted_phot=nan, raw_phot=1.2533333623410677e-17, fitted_phot_err=nan
# Skipping Bessell_U due to bad values: fitted_phot=nan, raw_phot=7.208956364169182e-18, fitted_phot_err=nan
# Skipping Bessell_V due to bad values: fitted_phot=nan, raw_phot=1.3206995897194258e-17, fitted_phot_err=nan
# Skipping Y due to bad values: fitted_phot=nan, raw_phot=2.1584346555011666e-18, fitted_phot_err=nan
# Skipping sdss_g due to bad values: fitted_phot=nan, raw_phot=5.447627733406685e-18, fitted_phot_err=nan
# Skipping sdss_i due to bad values: fitted_phot=nan, raw_phot=2.0459923131000762e-17, fitted_phot_err=nan
# Skipping sdss_r due to bad values: fitted_phot=nan, raw_phot=2.5799076901588478e-17, fitted_phot_err=nan
# Skipping sdss_z due to bad values: fitted_phot=nan, raw_phot=4.806989597801805e-18, fitted_phot_err=nan
# [DEBUG] Calling GP_interpolation_mangle (initial)
# ratios: []
# ratios normed: []
# ratios err: []
# ratios err normed: []
# mean: nan
# [DEBUG] Applying initial mangling mask
# /var/folders/0n/xfstb8sn23ldhmmxkvnlgk4c0000gn/T/ipykernel_86074/2037789350.py:267: RuntimeWarning: Mean of empty slice
#   norm = np.nanmean(ratios)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 8
#       5 new_spec= ReMangle_SingleSpectrumClass(snname=snname, twodim=True,\
#       6                 spec_file=f, verbose=True)
#       7 new_spec.load_extended_spec()
# ----> 8 result = new_spec.mangle_iteration_function()
#       9 new_spec.save_FINAL_spectrum()
#
# Cell In[17], line 419, in ReMangle_SingleSpectrumClass.mangle_iteration_function(self)
#     417 max_iteration = 5
#     418 for i in range(max_iteration):
# --> 419     print(f"[DEBUG] Iteration {i} - max(ratios-1): {np.max(np.abs(ratios-1.))}")
#     420     if max(np.abs(ratios-1.))>0.01:
#     421         print("[DEBUG] Calling calculate_ratios4mangling...")
#
# File /opt/anaconda3/envs/SED/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File /opt/anaconda3/envs/SED/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
# Directory containing your spectra files
data_dir = "/Users/ravkaur/Desktop/research/kilonova-SED/PyCoCo_templates/Outputs/iPTF13bvn/FINAL_spectra_2dim"

# Collect all files in the directory
spectra_files = sorted([f for f in os.listdir(data_dir) if f.endswith(".txt")])

# Lists to store results
mjds = []
wavelengths = []
fluxes = []

# Loop through all spectra files
for file in spectra_files:
    # Extract the MJD from the filename (assuming it starts with MJD)
    mjd = float(file.split("_")[0])
    mjds.append(mjd)

    # Load the data (assuming 3 columns: wavelength, flux, flux error)
    data = np.loadtxt(os.path.join(data_dir, file))
    wavelengths.append(data[:, 0])  # First column: wavelength
    fluxes.append(data[:, 1])       # Second column: flux

# Convert lists to numpy arrays for easier handling
mjds = np.array(mjds)
wavelengths = np.array(wavelengths, dtype=object)  # Allow variable-length arrays
fluxes = np.array(fluxes, dtype=object)

# Define a common wavelength grid (e.g., union or interpolation grid)
common_wavelengths = np.linspace(2000, 10000, 500)  # Adjust wavelength range and resolution

# Interpolate flux onto the common wavelength grid
fluxes_interpolated = []
for i in range(len(fluxes)):
    flux_interp = np.interp(common_wavelengths, wavelengths[i], fluxes[i], left=np.nan, right=np.nan)
    fluxes_interpolated.append(flux_interp)

fluxes_interpolated = np.array(fluxes_interpolated)

# Create a 2D plot
plt.figure(figsize=(10, 6))
plt.imshow(
    fluxes_interpolated.T, 
    aspect='auto', 
    extent=[mjds.min(), mjds.max(), common_wavelengths.min(), common_wavelengths.max()],
    origin='lower', 
    cmap='viridis', 
    norm=LogNorm(vmin=3.321846586518659e-05, vmax=0.04521411733143501)  # Adjust vmin/vmax as needed
)
#plt.colorbar(label=r"Flux (erg s$^{-1}$ cm$^{-2}$ Å$^{-1}$)")
plt.colorbar(label=r"Flux")
plt.xlabel("Days (MJD)")
plt.ylabel("Wavelength (Å)")
plt.title("SED Evolution")
plt.show()

# %%
print("Flux range:", np.nanmin(fluxes_interpolated), np.nanmax(fluxes_interpolated))
# Out:
# Flux range: 3.321846586518659e-05 0.04521411733143501

# %%
# Subtract the minimum MJD to get days from start
days_from_start = mjds - mjds.min()

# Create a 2D plot with days from start on the x-axis
plt.figure(figsize=(10, 6))
plt.imshow(
    fluxes_interpolated.T, 
    aspect='auto', 
    extent=[days_from_start.min(), days_from_start.max(), common_wavelengths.min(), common_wavelengths.max()],
    origin='lower', 
    cmap='viridis', 
    norm=LogNorm(vmin=3.321846586518659e-05, vmax=0.04521411733143501)  # Adjust vmin/vmax as needed
)
plt.colorbar(label=r"Flux")
plt.xlabel("Days from first detection")
plt.ylabel("Wavelength (Å)")
plt.title("SED Evolution")
plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
def create_lookup_table(data_dir, wavelength_range=(2000, 10000), wavelength_bins=10000):
    """
    Load spectra data from files, interpolate onto a common wavelength grid,
    and create a lookup table (DataFrame) for flux values.

    Parameters:
    - data_dir: str, path to the directory containing spectra files.
    - wavelength_range: tuple, min and max wavelength range for interpolation.
    - wavelength_bins: int, number of bins for wavelength interpolation.

    Returns:
    - lookup_table: pd.DataFrame, fluxes indexed by time and columns as wavelengths.
    - days_from_start: np.ndarray, time in days from the first MJD.
    - common_wavelengths: np.ndarray, the interpolated wavelength grid.
    """
    # Collect all spectra files
    spectra_files = sorted([f for f in os.listdir(data_dir) if f.endswith(".txt")])

    # Lists to store results
    mjds = []
    wavelengths = []
    fluxes = []

    # Loop through all spectra files
    for file in spectra_files:
        # Extract the MJD from the filename (assuming it starts with MJD)
        mjd = float(file.split("_")[0])
        mjds.append(mjd)

        # Load the data (assuming 3 columns: wavelength, flux, flux error)
        data = np.loadtxt(os.path.join(data_dir, file))
        wavelengths.append(data[:, 0])  # First column: wavelength
        fluxes.append(data[:, 1])       # Second column: flux

    # Convert lists to numpy arrays for easier handling
    mjds = np.array(mjds)
    wavelengths = np.array(wavelengths, dtype=object)  # Allow variable-length arrays
    fluxes = np.array(fluxes, dtype=object)

    # Define a common wavelength grid
    common_wavelengths = np.linspace(wavelength_range[0], wavelength_range[1], wavelength_bins)

    # Interpolate flux onto the common wavelength grid
    fluxes_interpolated = []
    for i in range(len(fluxes)):
        flux_interp = np.interp(common_wavelengths, wavelengths[i], fluxes[i], left=np.nan, right=np.nan)
        fluxes_interpolated.append(flux_interp)

    fluxes_interpolated = np.array(fluxes_interpolated)

    # Subtract the minimum MJD to get days from start
    days_from_start = mjds - mjds.min()

    # Create a pandas DataFrame for lookup
    lookup_table = pd.DataFrame(
        fluxes_interpolated,
        index=days_from_start,  # Time as index (days from start)
        columns=common_wavelengths  # Wavelength as columns
    )

    return lookup_table, days_from_start, common_wavelengths


def plot_spectrum(time_from_start, lookup_table, wavelengths):
    """
    Plot a spectrum (flux vs wavelength) for a given time.
    """
    # Find the closest time in the DataFrame
    closest_time = lookup_table.index[np.argmin(np.abs(lookup_table.index - time_from_start))]
    flux = lookup_table.loc[closest_time]

    # Plot the spectrum
    plt.figure(figsize=(8, 5))
    plt.plot(wavelengths, flux, label=f"Time = {closest_time:.2f} days")
    plt.xlabel("Wavelength (Å)")
    plt.ylabel(r"Flux (erg s$^{-1}$ cm$^{-2}$ Å$^{-1}$)")
    plt.title("Spectrum at Time {:.2f} days".format(closest_time))
    plt.legend()
    plt.grid()
    plt.show()


def plot_lightcurve(wavelength, lookup_table):
    """
    Plot a light curve (flux vs time) for a given wavelength.
    """
    # Find the closest wavelength in the DataFrame
    closest_wavelength = lookup_table.columns[np.argmin(np.abs(lookup_table.columns - wavelength))]
    flux = lookup_table[closest_wavelength]

    # Plot the light curve
    plt.figure(figsize=(8, 5))
    plt.scatter(lookup_table.index, flux, label=f"Wavelength = {closest_wavelength:.2f} Å")
    plt.xlabel("Time (days from start)")
    plt.ylabel(r"Flux (erg s$^{-1}$ cm$^{-2}$ Å$^{-1}$)")
    plt.title("Lightcurve at Wavelength {:.2f} Å".format(closest_wavelength))
    plt.legend()
    plt.grid()
    plt.show()


def plot_sed_evolution(lookup_table, common_wavelengths, days_from_start, vmin=3.321846586518659e-05, vmax=0.04521411733143501):
    """
    Create a 2D plot of spectral density evolution (time vs wavelength vs flux).

    Parameters:
    - lookup_table: pd.DataFrame, flux values with time as index and wavelengths as columns.
    - common_wavelengths: np.ndarray, the wavelength grid used for interpolation.
    - days_from_start: np.ndarray, the time in days from the first detection.
    - vmin: float, minimum flux value for color scaling.
    - vmax: float, maximum flux value for color scaling.
    """
    plt.figure(figsize=(10, 6))
    plt.imshow(
        lookup_table.values.T, 
        aspect='auto', 
        extent=[days_from_start.min(), days_from_start.max(), common_wavelengths.min(), common_wavelengths.max()],
        origin='lower', 
        cmap='viridis', 
        norm=LogNorm(vmin=vmin, vmax=vmax)
    )
    plt.colorbar(label=r"Flux (erg s$^{-1}$ cm$^{-2}$ Å$^{-1}$)")
    plt.xlabel("Days from first detection")
    plt.ylabel("Wavelength (Å)")
    plt.title("SED Evolution")
    plt.show()

# %%
# Example Usage:
# Path to directory with spectra files
data_dir = "/Users/ravkaur/Desktop/research/kilonova-SED/PyCoCo_templates/Outputs/iPTF13bvn/FINAL_spectra_2dim"

# Create the lookup table
lookup_table, days_from_start, common_wavelengths = create_lookup_table(data_dir)

# %%
# Plot a spectrum at 20 days from start
plot_spectrum(20, lookup_table, common_wavelengths)

# %%
# Plot a light curve at 5000 Å
plot_lightcurve(4500, lookup_table)

# %%
# Plot the SED evolution
plot_sed_evolution(lookup_table, common_wavelengths, days_from_start)
